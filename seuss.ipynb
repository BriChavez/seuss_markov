# %%
import re
import string
from numpy.random import choice
import random
from pprint import pprint

def markov_dict():
    # create empty dictionary
    word_freqs = {}
    # open txt file and read to string, string to lower
    with open('seuss_script.txt', 'r') as sonnet_file:
       sonnets = sonnet_file.read()
       sonnets = sonnets.lower()
        # use regex to split text into words and punctuation
        words = re.sub('['+string.punctuation+']', '', sonnets).split()
        past_word = ""
        frequency = {}
        # for loop that runs over every word in test
        for word in words:
        
            -past_word = word
            return word_freqs


# markov_dict()
print(markov_dict())

# %%
import re
import string
from numpy.random import choice
import random
from pprint import pprint

def markov_dict():
    """create a dict of how what words follow which and how many times they did"""
    word_freqs = {}
    # create a dictionary
    with open('./seuss_script.txt', 'r') as seuss_script:
        # open txt file and read to string
        seussical = seuss_script.read()
        # lowercase all letters
        seussical = seussical.lower()
    # use regex to split text into words and punctuation
    words = re.sub('['+string.punctuation+']', '', seussical).split()
    past_word = []
    
    # for loop that runs over every word in test
    for word in words:
        # if past_word is in dict, assign it to 'frequency'
        if past_word in word_freqs:
            frequency = word_freqs[past_word]
        # if not, create empty dictionary with past_word as the key and frequency as the value
        else:
            frequency = {}
            word_freqs[past_word] = frequency

        if word in frequency:
            frequency[word] += 1
        else:
            frequency[word] = 1

        past_word = word

    return word_freqs

markov_dict()
# # name our new dictionary of words and count of next possible words to a new variable
# seuss_dict = markov_dict()
# # print(seuss_dict)
# pprint(seuss_dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_142948/1175604640.py in <module>
#      37     return word_freqs
#      38
# ---> 39 markov_dict()
#      40 # # name our new dictionary of words and count of next possible words to a new variable
#      41 # seuss_dict = markov_dict()
#
# /tmp/ipykernel_142948/1175604640.py in markov_dict()
#      21     for word in words:
#      22         # if past_word is in dict, assign it to 'frequency'
# ---> 23         if past_word in word_freqs:
#      24             frequency = word_freqs[past_word]
#      25         # if not, create empty dictionary with past_word as the key and frequency as the value
#
# TypeError: unhashable type: 'list'

# %%
"""start the story"""

# name variable with the first word in our list of words
first_word = random.choice(seuss_string)
print(first_word)
# name the first word of our story as 
global story
story = []
def start_story(list):
    """function to start the story"""
    if story == []:
        # set story up with a first word
        story.append(first_word)
    else:
        # dont start the story if its already been started
        pass
    return story
start_story(seuss_string)
# call function on our list of words from the text
seuss_list = seuss_string
# Out:
# them

# %%
# What am I doing? Because initially wordfreq is empty you can't assign it to wordfreq[word] for the first time (it will raise key exception error). So I used setdefault dict method.

# dict.setdefault(key, default=None) is similar to get(), but will set dict[key]=default if key is not already in dict. So for the first time when a new word comes, I set it with 0 in dict using setdefault then add 1 and assign to the same dict.


from pprint import pprint
import random
from numpy.random import choice
import string
from collections import defaultdict
import re
with open('~/Desktop/file') as f:
    words = f.read()
    wordfreq = {}
    for word in words.replace(',', ' ').split():
        wordfreq[word] = wordfreq.setdefault(word, 0) + 1
print wordfreq


for i in re.split(r"[,\s]+", words):

    re.findall(r'[\w]+', words)


$ cat work.py
wordfreq = {}
with open('file') as f:
    for line in f:
        for word in re.findall(r'[\w]+', line.lower()):
            wordfreq[word] = wordfreq.setdefault(word, 0) + 1

print wordfreq


dict(Counter(t.replace(',', '').replace('.', '').split()))


wordDict = defaultdict(int)
text = 'this is the textfile, and it is used to take words and count'.split(
    " ")
for word in text:
    wordDict[word] += 1
"""explanation: we initialize a default dictionary whose values are of the type int. This way the default value for any key will be 0 and we don't need to check if a key is present in the dictionary or not. we then split the text with the spaces into a list of words. then we iterate through the list and increment the count of the word's count.
"""


def markov_dict():
    # create empty dictionary
    word_freqs = {}
    # open txt file and read to string, string to lower
    with open('seuss_script.txt', 'r') as sonnet_file:
       sonnets = sonnet_file.read()
       sonnets = sonnets.lower()

# %%
from pprint import pprint
import random
from numpy.random import choice
import string
from collections import defaultdict
import re

word_freqs = {}
# open txt file and read to string, string to lower
with open('seuss_script.txt', 'r') as sonnet_file:
    sonnets = sonnet_file.read()
    sonnets = sonnets.lower()

wordDict = defaultdict(int)
text = re.findall(r"[\w']+|[., !?;]", sonnets)
for word in text:
    wordDict[word] += 1

# %%
import sys
# for word in "Hi, how are you?".replace(',', ' ').split():

# str.split(str="", num=string.count(str)) m

# if word not in wordfreq: wordfreq[word] = 1
filename = sys.argv[1]
fp = open(filename)
data = fp.read()
words = data.split()
fp.close()

unwanted_chars = ".,-_ (and so on)"
wordfreq = {}
for raw_word in words:
    word = raw_word.strip(unwanted_chars)
    if word not in wordfreq:
        wordfreq[word] = 0
    wordfreq[word] += 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3821/892620274.py in <module>
#       1 for outer_word, inner_dict in seuss_dict.items():
#       2     for outer_word in seuss_dict.items():
# ----> 3         print(type(seuss_dict[2]))
#       4         # print(hmm)
#       5     # if outer_word == current_word:
#
# KeyError: 2

# %%
this_dict = seuss_dict

# %%
for value in this_dict:
    if value == current_word:
        new_word_dict = this_dict.values()
        print(value, new_word_dict)
# Out:
# them dict_values([{'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}, {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}, {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}, {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}, {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}, {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}, {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 's ...

# %%
# """start the story"""


# def start_story(list):
#     """function to start the story"""
#     if story == []:
#         # set story up with a first word
#         story.append(first_word)
#         # call the global variable current_word so we can change it
#         # global current_word
#         # turn the first word into the current word
#         # current_word = first_word
#         # print(current_word)
#     else:
#         # dont start the story if its already been started
#         pass
#     return story
# start_story(seuss_string)
# # call function on our list of words from the text
# seuss_list = seuss_string
# # print(story)

# # reset current word to the last word of the story
# current_word = story[-1]
# print(current_word)
# Out:
# green

# %%
from numpy.random import choice

current_word = story[-1]
# print(current_word)
# def next_up(list):
# if len(story) == 1:
#     print("okay")

for next_up, inner_dict in seuss_dict.items():
    
    if next_up == current_word:
        total_occurances = inner_dict.values()
        word_self_total = inner_dict.items()
        word_num = word_self_total
        total = sum(total_occurances)
        probs = []
        hopefuls = []
        likely = []
        for number in total_occurances:
            percent = number / total
            probs.append(percent)
        
        for word, num in word_self_total:
            hopefuls.append(word)
            likely.append(num)
        
        rng_says = choice(hopefuls, p = probs)
        print(rng_says)
            # random.choices(hopefuls)
                # rng_chooses = choice(hopefuls, p=probs)


                # print(rng_chooses)



        # for number in total_occurances:
        #     # total = sum(total_occurances)
        #     probs = number / total
        #     # print(type(number))
        #     # print(type(total_occurances))
        #     print(probs)



        # for key in inner_dict:
        #     print(key + ':', inner_dict[key])
            # print(next_up)
# Out:
# a

# %%
current_word = story[-1]
# print(current_word)
# def next_up(list):
# if len(story) == 1:
#     print("okay")

for next_up, inner_dict in seuss_dict.items():
    total_occurances = inner_dict.values()
    word_self_total = inner_dict.items()
    if next_up == current_word:
        word_num = word_self_total

        # total = sum(total_occurances)
        # print(total)
        # for number in total_occurances:
        #     # total = sum(total_occurances)
        #     probs = number / total
        #     # print(type(number))
        #     # print(type(total_occurances))
        #     print(probs)
        # for key in inner_dict:
        #     print(key + ':', inner_dict[key])
        #     # print(next_up)

# %%
current_word = story[-1]
print(current_word)
# def next_up(list):
if len(story) == 1:
    print("okay")
# if story[0] == first_word:
for p_id, p_info in seuss_dict.items():
    print("\nPerson ID:", p_id)
    if p_id == current_word:
        for key in p_info:
            print(key + ':', p_info[key])
            print(p_info)

# %%
# def next_up(list):

# if story[0] == first_word:
for current_word, word_count in seuss_dict.items():
    print("\ncurrent_word", current_word)
    if current_word == current_word:
        for how_often in word_count[how_often]:
            # print(word_count[how_often])
            # print(how_often + ':', word_count[how_often])
            # print(type(word_count[how_often]))
            print(how_often)

# %%
"""start the story"""

# name variable with the first word in our list of words
first_word = seuss_string[0]
story = []
# current_word = "yay"
def start_story(list):
    """function to start the story"""
    if story == []:
        # set story up with a first word
        story.append(first_word)
        # call the global variable current_word so we can change it
        # global current_word
        # turn the first word into the current word
        # current_word = first_word
        # print(current_word)
    else:
        # dont start the story if its already been started
        pass
    return story
start_story(seuss_string)
# call function on our list of words from the text
seuss_list = seuss_string
# print(story)

# reset current word to the last word of the story
current_word = story[-1]
print(current_word)

# %%
import re
import string


def markov_dict():
    # create empty dictionary
    # global word_freqs
    # global frequency
    # global past_word
    # open txt file and read to string, string to lower
    with open('./seuss_script.txt', 'r') as seuss_script:
        seussical = seuss_script.read()
        seussical = seussical.lower()
    # use regex to split text into words and punctuation
    words = re.sub('['+string.punctuation+']', '', seussical).split()
    first_word = words[0]
    story = []
    # past_word = story[-1]
    
    # start the story

    first_word = words[0]
    story = []
    

    def start_story(list):
        """function to start the story"""
        if story == []:
            # set story up with a first word
            story.append(first_word)
            # turn the first word into the current wird
            current_word = first_word
        else:
            pass
        return story, current_word
    start_story(words)
    
    

            # for d, k, v in seuss_dict.items():
                
                # next_up(story)
                # next_up = k, y[k]
#             return line_up
# for word in line_up:
    # if len(story) == len(first_word):
    #     story = story + [' cat']
    #     # do the thing for finding the second word
    #     # story.append(past_word)
    #     print(story)


    # frequency = {}

    # for loop that runs over every word in test
    # print(story)
    # print(past_word)





seuss_dict = markov_dict()
# print(seuss_dict)

# def line_up
# for word, next in seuss_dict.items():
#     append(word)
#     # and

# def seuss_script(dict):
#     story = []
#     last_word = []
#     for word in dict:
#         if word not in last_word:
#             story = append.story(word)
# def line_up(dictionary):
#     for x, y in dictionary.items():

#         for k in y:
#             line_up = x , k, y[k]
#             # next_up = k, y[k]
#             return line_up
# for word in line_up:


# # this word print
# # next word is based of the probability of the next word
# #  get value of all


#             # current_next_chance = {x},[k],[y[k]]
#                 print(line_up)
#                 print(next_up)
# line_up(seuss_dict)

# print()

# def line_up(dictionary):
#     for x, y in dictionary.items():

#         for k in y:
#             line_up = x, k, y[k]


# for woird in dictuonary
#     for next in word
#        tot percent = sum of count
# def line_up(dictionary):
#     for x, y in dictionary.items():

#         for k in y:
#             line_up = x , k, y[k]
#             # next_up = k, y[k]
#             return line_up
# for word in line_up:
#         next.value/sum of count
#         rng based off percent
#             next word = current word
#             story. append.

# seuss_it_up(seuss_dict)
# """
# take key.
# take next word.
# calculate chance with their value/sum of.
# rng the word.
# add that word to story.
# grab that word from the dict key.
# make that word key.
# calculate next word."""

# for value_dict in input_dict.values():
#     print(sum(value_dict.values()))

# %%
import collections
global story


def seuss_it_up(dict):
    total_follows = []
    for word, int in dict.items():
        likely = int
        print(likely)
    #         if word not in total_follows:
    #             total_follows.append(word)
    # print(total_follows)
    last_word = total_follows.endswith(current_word)
    if current_word == last_word:
        

# ini_dict = [{'a': 5, 'b': 10, 'c': 90},
#             {'a': 45, 'b': 78},
#             {'a': 90, 'c': 10}]
# SEUSS_DICT =

# word = [{next: prob}]
# # printing initial dictionary
# print("initial dictionary", str(ini_dict))

# # sum the values with same keys
# counter = collections.Counter()
# for d in ini_dict:
#     counter.update(d)

# result = dict(counter)


# print("resultant dictionary : ", str(counter))

seuss_it_up(seuss_dict)


# Initialising list of dictionary

# for word in dict:
#     for next in word.items():
#         counts = next[1]
#         # total = sum(counts)

#         print(counts)
# for key, value in next.items():

#     return    # for value in key:

# if word in story: psss
#      else:
#          for

# current = key
# likelyhood = value
# print(current, likelyhood)

# print(next_word)
# print(key, value)

# %%
# for id, info in D.items():
#     print("\nEmployee ID:", id)
#     for key in info:
#         print(key + ':', info[key])

# for key in seuss_dict.keys():
#     for key in key.keys():
#         print(value)


# def get_keys(dictionary):
#     inner_pairs = []
#     for key, value in dictionary.items():
#         if type(value) is dict:
#             new_keys = get_keys(value)
#             inner_pairs.append(key)
#             for innerkey in new_keys:
#                 inner_pairs.append(f'{key}/{innerkey}')
#         else:
#             inner_pairs.append(key)
#     return inner_pairs

# for k, v, items in seuss_dict.keys():
#     print(k[v][items])

# for key, values in seuss_dict:
#     past = key
#     next = values
#     print(past)

# %%
somethin= this_dict.get(current_word)
from pprint import pprint
pprint(seuss_dict)
# for dict in this_dict.items():
    
#     if this_dict.items == current_word:
#         word_dict = {}
#         print(this_dict)
#     else:
#         pass
#         # new_keys = word_probs(value)
#         # inner_pairs.append(key)
#         # for inner_key in new_keys:
#         #     inner_pairs.append(f'{key}:{inner_key}')
#     # if type(value) is dict:    
#     # else:
#     #     inner_pairs.append(key)
# print(inner_pairs)
# Out:
# {'': {'a': 56,
#       'am': 4,
#       'and': 26,
#       'anywhere': 8,
#       'are': 2,
#       'be': 4,
#       'boat': 3,
#       'box': 7,
#       'car': 7,
#       'could': 14,
#       'dark': 7,
#       'do': 37,
#       'eat': 23,
#       'eggs': 12,
#       'fox': 7,
#       'goat': 4,
#       'good': 2,
#       'greem': 1,
#       'green': 11,
#       'ham': 12,
#       'here': 11,
#       'house': 8,
#       'i': 71,
#       'if': 1,
#       'in': 40,
#       'let': 4,
#       'like': 44,
#       'may': 4,
#       'me': 4,
#       'mouse': 7,
#       'not': 82,
#       'on': 6,
#       'or': 8,
#       'rain': 4,
#       'sam': 7,
#       'samiam': 11,
#       'say': 5,
#       'see': 4,
#       'so': 5,
#       'thank': 2,
#       'that': 3,
#       'the': 11,
#       'them': 57,
#       'themsamiam': 1,
#       'then': 1,
#       'there': 9,
#       'they': 2,
#       'train': 8,
#       'tree': 6,
#       'try': 4,
#       'will': 18,
#       'with': 18,
#       'would': 27,
#       'you': 34},
#  'a': {'a': 56,
#        'am': 4,
#        'and': 26,
#        'anywhere': 8,
#        'are': 2,
#        'be': 4,
#        'boat': 3,
#        'box': 7,
#        'car': 7,
#        'could': 14,
#        'dark': 7,
#        'do': 37,
#        'eat': 23,
#        'eggs': 12,
#        'fox': 7,
#        'goat': 4,
#        'good': 2,
#        'greem': 1,
#        'green': 11,
#        'ham': 12,
#        'here': 11,
#        'house': 8,
#        'i': 71,
#        'if': 1,
#        'in': 40,
#        'let': 4,
#        'like': 44,
#        'may': 4,
#        'me': 4,
#        'mouse': 7,
#        'not': 82,
#        'on': 6,
#        'or': 8,
#        'rain': 4,
#        'sam': 7,
#        'samiam': 11,
#        'say': 5,
#        'see': 4,
#        'so': 5,
#        'thank': 2,
#        'that': 3,
#        'the': 11,
#        'them': 57,
#        'themsamiam': 1,
#        'then': 1,
#        'there': 9,
#        'they': 2,
#        'train': 8,
#        'tree': 6,
#        'try': 4,
#        'will': 18,
#        'with': 18,
#        'would': 27,
#        'you': 34},
#  'am': {'a': 56,
#         'am': 4,
#         'and': 26,
#         'anywhere': 8,
#         'are': 2,
#         'be': 4,
#         'boat': 3,
#         'box': 7,
#         'car': 7,
#         'could': 14,
#         'dark': 7,
#         'do': 37,
#         'eat': 23,
#         'eggs': 12,
#         'fox': 7,
#         'goat': 4,
#         'good': 2,
#         'greem': 1,
#         'green': 11,
#         'ham': 12,
#         'here': 11,
#         'house': 8,
#         'i': 71,
#         'if': 1,
#         'in': 40,
#         'let': 4,
#         'like': 44,
#         'may': 4,
#         'me': 4,
#         'mouse': 7,
#         'not': 82,
#         'on': 6,
#         'or': 8,
#         'rain': 4,
#         'sam': 7,
#         'samiam': 11,
#         'say': 5,
#         'see': 4,
#         'so': 5,
#         'thank': 2,
#         'that': 3,
#         'the': 11,
#         'them': 57,
#         'themsamiam': 1,
#         'then': 1,
#         'there': 9,
#         'they': 2,
#         'train': 8,
#         'tree': 6,
#         'try': 4,
#         'will': 18,
#         'with': 18,
#         'would': 27,
#         'you': 34},
#  'and': {'a': 56,
#          'am': 4,
#          'and': 26,
#          'anywhere': 8,
#          'are': 2,
#          'be': 4,
#          'boat': 3,
#          'box': 7,
#          'car': 7,
#          'could': 14,
#          'dark': 7,
#          'do': 37,
#          'eat': 23,
#          'eggs': 12,
#          'fox': 7,
#          'goat': 4,
#          'good': 2,
#          'greem': 1,
#          'green': 11,
#          'ham': 12,
#          'here': 11,
#          'house': 8,
#          'i': 71,
#          'if': 1,
#          'in': 40,
#          'let': 4,
#          'like': 44,
#          'may': 4,
#          'me': 4,
#          'mouse': 7,
#          'not': 82,
#          'on': 6,
#          'or': 8,
#          'rain': 4,
#          'sam': 7,
#          'samiam': 11,
#          'say': 5,
#          'see': 4,
#          'so': 5,
#          'thank': 2,
#          'that': 3,
#          'the': 11,
#          'them': 57,
#          'themsamiam': 1,
#          'then': 1,
#          'there': 9,
#          'they': 2,
#          'train': 8,
#          'tree': 6,
#          'try': 4,
#          'will': 18,
#          'with': 18,
#          'would': 27,
#          'you': 34},
#  'anywhere': {'a': 56,
#               'am': 4,
#               'and': 26,
#               'anywhere': 8,
#               'are': 2,
#               'be': 4,
#               'boat': 3,
#               'box': 7,
#               'car': 7,
#               'could': 14,
#               'dark': 7,
#               'do': 37,
#               'eat': 23,
#               'eggs': 12,
#               'fox': 7,
#               'goat': 4,
#               'good': 2,
#               'greem': 1,
#               'green': 11,
#               'ham': 12,
#               'here': 11,
#               'house': 8,
#               'i': 71,
#               'if': 1,
#               'in': 40,
#               'let': 4,
#               'like': 44,
#               'may': 4,
#               'me': 4,
#               'mouse': 7,
#               'not': 82,
#               'on': 6,
#               'or': 8,
#               'rain': 4,
#               'sam': 7,
#               'samiam': 11,
#               'say': 5,
#               'see': 4,
#               'so': 5,
#               'thank': 2,
#               'that': 3,
#               'the': 11,
#               'them': 57,
#               'themsamiam': 1,
#               'then': 1,
#               'there': 9,
#               'they': 2,
#               'train': 8,
#               'tree': 6,
#               'try': 4,
#               'will': 18,
#               'with': 18,
#               'would': 27,
#               'you': 34},
#  'are': {'a': 56,
#          'am': 4,
#          'and': 26,
#          'anywhere': 8,
#          'are': 2,
#          'be': 4,
#          'boat': 3,
#          'box': 7,
#          'car': 7,
#          'could': 14,
#          'dark': 7,
#          'do': 37,
#          'eat': 23,
#          'eggs': 12,
#          'fox': 7,
#          'goat': 4,
#          'good': 2,
#          'greem': 1,
#          'green': 11,
#          'ham': 12,
#          'here': 11,
#          'house': 8,
#          'i': 71,
#          'if': 1,
#          'in': 40,
#          'let': 4,
#          'like': 44,
#          'may': 4,
#          'me': 4,
#          'mouse': 7,
#          'not': 82,
#          'on': 6,
#          'or': 8,
#          'rain': 4,
#          'sam': 7,
#          'samiam': 11,
#          'say': 5,
#          'see': 4,
#          'so': 5,
#          'thank': 2,
#          'that': 3,
#          'the': 11,
#          'them': 57,
#          'themsamiam': 1,
#          'then': 1,
#          'there': 9,
#          'they': 2,
#          'train': 8,
#          'tree': 6,
#          'try': 4,
#          'will': 18,
#          'with': 18,
#          'would': 27,
#          'you': 34},
#  'be': {'a': 56,
#         'am': 4,
#         'and': 26,
#         'anywhere': 8,
#         'are': 2,
#         'be': 4,
#         'boat': 3,
#         'box': 7,
#         'car': 7,
#         'could': 14,
#         'dark': 7,
#         'do': 37,
#         'eat': 23,
#         'eggs': 12,
#         'fox': 7,
#         'goat': 4,
#         'good': 2,
#         'greem': 1,
#         'green': 11,
#         'ham': 12,
#         'here': 11,
#         'house': 8,
#         'i': 71,
#         'if': 1,
#         'in': 40,
#         'let': 4,
#         'like': 44,
#         'may': 4,
#         'me': 4,
#         'mouse': 7,
#         'not': 82,
#         'on': 6,
#         'or': 8,
#         'rain': 4,
#         'sam': 7,
#         'samiam': 11,
#         'say': 5,
#         'see': 4,
#         'so': 5,
#         'thank': 2,
#         'that': 3,
#         'the': 11,
#         'them': 57,
#         'themsamiam': 1,
#         'then': 1,
#         'there': 9,
#         'they': 2,
#         'train': 8,
#         'tree': 6,
#         'try': 4,
#         'will': 18,
#         'with': 18,
#         'would': 27,
#         'you': 34},
#  'boat': {'a': 56,
#           'am': 4,
#           'and': 26,
#           'anywhere': 8,
#           'are': 2,
#           'be': 4,
#           'boat': 3,
#           'box': 7,
#           'car': 7,
#           'could': 14,
#           'dark': 7,
#           'do': 37,
#           'eat': 23,
#           'eggs': 12,
#           'fox': 7,
#           'goat': 4,
#           'good': 2,
#           'greem': 1,
#           'green': 11,
#           'ham': 12,
#           'here': 11,
#           'house': 8,
#           'i': 71,
#           'if': 1,
#           'in': 40,
#           'let': 4,
#           'like': 44,
#           'may': 4,
#           'me': 4,
#           'mouse': 7,
#           'not': 82,
#           'on': 6,
#           'or': 8,
#           'rain': 4,
#           'sam': 7,
#           'samiam': 11,
#           'say': 5,
#           'see': 4,
#           'so': 5,
#           'thank': 2,
#           'that': 3,
#           'the': 11,
#           'them': 57,
#           'themsamiam': 1,
#           'then': 1,
#           'there': 9,
#           'they': 2,
#           'train': 8,
#           'tree': 6,
#           'try': 4,
#           'will': 18,
#           'with': 18,
#           'would': 27,
#           'you': 34},
#  'box': {'a': 56,
#          'am': 4,
#          'and': 26,
#          'anywhere': 8,
#          'are': 2,
#          'be': 4,
#          'boat': 3,
#          'box': 7,
#          'car': 7,
#          'could': 14,
#          'dark': 7,
#          'do': 37,
#          'eat': 23,
#          'eggs': 12,
#          'fox': 7,
#          'goat': 4,
#          'good': 2,
#          'greem': 1,
#          'green': 11,
#          'ham': 12,
#          'here': 11,
#          'house': 8,
#          'i': 71,
#          'if': 1,
#          'in': 40,
#          'let': 4,
#          'like': 44,
#          'may': 4,
#          'me': 4,
#          'mouse': 7,
#          'not': 82,
#          'on': 6,
#          'or': 8,
#          'rain': 4,
#          'sam': 7,
#          'samiam': 11,
#          'say': 5,
#          'see': 4,
#          'so': 5,
#          'thank': 2,
#          'that': 3,
#          'the': 11,
#          'them': 57,
#          'themsamiam': 1,
#          'then': 1,
#          'there': 9,
#          'they': 2,
#          'train': 8,
#          'tree': 6,
#          'try': 4,
#          'will': 18,
#          'with': 18,
#          'would': 27,
#          'you': 34},
#  'car': {'a': 56,
#          'am': 4,
#          'and': 26,
#          'anywhere': 8,
#          'are': 2,
#          'be': 4,
#          'boat': 3,
#          'box': 7,
#          'car': 7,
#          'could': 14,
#          'dark': 7,
#          'do': 37,
#          'eat': 23,
#          'eggs': 12,
#          'fox': 7,
#          'goat': 4,
#          'good': 2,
#          'greem': 1,
#          'green': 11,
#          'ham': 12,
#          'here': 11,
#          'house': 8,
#          'i': 71,
#          'if': 1,
#          'in': 40,
#          'let': 4,
#          'like': 44,
#          'may': 4,
#          'me': 4,
#          'mouse': 7,
#          'not': 82,
#          'on': 6,
#          'or': 8,
#          'rain': 4,
#          'sam': 7,
#          'samiam': 11,
#          'say': 5,
#          'see': 4,
#          'so': 5,
#          'thank': 2,
#          'that': 3,
#          'the': 11,
#          'them': 57,
#          'themsamiam': 1,
#          'then': 1,
#          'there': 9,
#          'they': 2,
#          'train': 8,
#          'tree': 6,
#          'try': 4,
#          'will': 18,
#          'with': 18,
#          'would': 27,
#          'you': 34},
#  'could': {'a': 56,
#            'am': 4,
#            'and': 26,
#            'anywhere': 8,
#            'are': 2,
#            'be': 4,
#            'boat': 3,
#            'box': 7,
#            'car': 7,
#            'could': 14,
#            'dark': 7,
#            'do': 37,
#            'eat': 23,
#            'eggs': 12,
#            'fox': 7,
#            'goat': 4,
#            'good': 2,
#            'greem': 1,
#            'green': 11,
#            'ham': 12,
#            'here': 11,
#            'house': 8,
#            'i': 71,
#            'if': 1,
#            'in': 40,
#            'let': 4,
#            'like': 44,
#            'may': 4,
#            'me': 4,
#            'mouse': 7,
#            'not': 82,
#            'on': 6,
#            'or': 8,
#            'rain': 4,
#            'sam': 7,
#            'samiam': 11,
#            'say': 5,
#            'see': 4,
#            'so': 5,
#            'thank': 2,
#            'that': 3,
#            'the': 11,
#            'them': 57,
#            'themsamiam': 1,
#            'then': 1,
#            'there': 9,
#            'they': 2,
#            'train': 8,
#            'tree': 6,
#            'try': 4,
#            'will': 18,
#            'with': 18,
#            'would': 27,
#            'you': 34},
#  'dark': {'a': 56,
#           'am': 4,
#           'and': 26,
#           'anywhere': 8,
#           'are': 2,
#           'be': 4,
#           'boat': 3,
#           'box': 7,
#           'car': 7,
#           'could': 14,
#           'dark': 7,
#           'do': 37,
#           'eat': 23,
#           'eggs': 12,
#           'fox': 7,
#           'goat': 4,
#           'good': 2,
#           'greem': 1,
#           'green': 11,
#           'ham': 12,
#           'here': 11,
#           'house': 8,
#           'i': 71,
#           'if': 1,
#           'in': 40,
#           'let': 4,
#           'like': 44,
#           'may': 4,
#           'me': 4,
#           'mouse': 7,
#           'not': 82,
#           'on': 6,
#           'or': 8,
#           'rain': 4,
#           'sam': 7,
#           'samiam': 11,
#           'say': 5,
#           'see': 4,
#           'so': 5,
#           'thank': 2,
#           'that': 3,
#           'the': 11,
#           'them': 57,
#           'themsamiam': 1,
#           'then': 1,
#           'there': 9,
#           'they': 2,
#           'train': 8,
#           'tree': 6,
#           'try': 4,
#           'will': 18,
#           'with': 18,
#           'would': 27,
#           'you': 34},
#  'do': {'a': 56,
#         'am': 4,
#         'and': 26,
#         'anywhere': 8,
#         'are': 2,
#         'be': 4,
#         'boat': 3,
#         'box': 7,
#         'car': 7,
#         'could': 14,
#         'dark': 7,
#         'do': 37,
#         'eat': 23,
#         'eggs': 12,
#         'fox': 7,
#         'goat': 4,
#         'good': 2,
#         'greem': 1,
#         'green': 11,
#         'ham': 12,
#         'here': 11,
#         'house': 8,
#         'i': 71,
#         'if': 1,
#         'in': 40,
#         'let': 4,
#         'like': 44,
#         'may': 4,
#         'me': 4,
#         'mouse': 7,
#         'not': 82,
#         'on': 6,
#         'or': 8,
#         'rain': 4,
#         'sam': 7,
#         'samiam': 11,
#         'say': 5,
#         'see': 4,
#         'so': 5,
#         'thank': 2,
#         'that': 3,
#         'the': 11,
#         'them': 57,
#         'themsamiam': 1,
#         'then': 1,
#         'there': 9,
#         'they': 2,
#         'train': 8,
#         'tree': 6,
#         'try': 4,
#         'will': 18,
#         'with': 18,
#         'would': 27,
#         'you': 34},
#  'eat': {'a': 56,
#          'am': 4,
#          'and': 26,
#          'anywhere': 8,
#          'are': 2,
#          'be': 4,
#          'boat': 3,
#          'box': 7,
#          'car': 7,
#          'could': 14,
#          'dark': 7,
#          'do': 37,
#          'eat': 23,
#          'eggs': 12,
#          'fox': 7,
#          'goat': 4,
#          'good': 2,
#          'greem': 1,
#          'green': 11,
#          'ham': 12,
#          'here': 11,
#          'house': 8,
#          'i': 71,
#          'if': 1,
#          'in': 40,
#          'let': 4,
#          'like': 44,
#          'may': 4,
#          'me': 4,
#          'mouse': 7,
#          'not': 82,
#          'on': 6,
#          'or': 8,
#          'rain': 4,
#          'sam': 7,
#          'samiam': 11,
#          'say': 5,
#          'see': 4,
#          'so': 5,
#          'thank': 2,
#          'that': 3,
#          'the': 11,
#          'them': 57,
#          'themsamiam': 1,
#          'then': 1,
#          'there': 9,
#          'they': 2,
#          'train': 8,
#          'tree': 6,
#          'try': 4,
#          'will': 18,
#          'with': 18,
#          'would': 27,
#          'you': 34},
#  'eggs': {'a': 56,
#           'am': 4,
#           'and': 26,
#           'anywhere': 8,
#           'are': 2,
#           'be': 4,
#           'boat': 3,
#           'box': 7,
#           'car': 7,
#           'could': 14,
#           'dark': 7,
#           'do': 37,
#           'eat': 23,
#           'eggs': 12,
#           'fox': 7,
#           'goat': 4,
#           'good': 2,
#           'greem': 1,
#           'green': 11,
#           'ham': 12,
#           'here': 11,
#           'house': 8,
#           'i': 71,
#           'if': 1,
#           'in': 40,
#           'let': 4,
#           'like': 44,
#           'may': 4,
#           'me': 4,
#           'mouse': 7,
#           'not': 82,
#           'on': 6,
#           'or': 8,
#           'rain': 4,
#           'sam': 7,
#           'samiam': 11,
#           'say': 5,
#           'see': 4,
#           'so': 5,
#           'thank': 2,
#           'that': 3,
#           'the': 11,
#           'them': 57,
#           'themsamiam': 1,
#           'then': 1,
#           'there': 9,
#           'they': 2,
#           'train': 8,
#           'tree': 6,
#           'try': 4,
#           'will': 18,
#           'with': 18,
#           'would': 27,
#           'you': 34},
#  'fox': {'a': 56,
#          'am': 4,
#          'and': 26,
#          'anywhere': 8,
#          'are': 2,
#          'be': 4,
#          'boat': 3,
#          'box': 7,
#          'car': 7,
#          'could': 14,
#          'dark': 7,
#          'do': 37,
#          'eat': 23,
#          'eggs': 12,
#          'fox': 7,
#          'goat': 4,
#          'good': 2,
#          'greem': 1,
#          'green': 11,
#          'ham': 12,
#          'here': 11,
#          'house': 8,
#          'i': 71,
#          'if': 1,
#          'in': 40,
#          'let': 4,
#          'like': 44,
#          'may': 4,
#          'me': 4,
#          'mouse': 7,
#          'not': 82,
#          'on': 6,
#          'or': 8,
#          'rain': 4,
#          'sam': 7,
#          'samiam': 11,
#          'say': 5,
#          'see': 4,
#          'so': 5,
#          'thank': 2,
#          'that': 3,
#          'the': 11,
#          'them': 57,
#          'themsamiam': 1,
#          'then': 1,
#          'there': 9,
#          'they': 2,
#          'train': 8,
#          'tree': 6,
#          'try': 4,
#          'will': 18,
#          'with': 18,
#          'would': 27,
#          'you': 34},
#  'goat': {'a': 56,
#           'am': 4,
#           'and': 26,
#           'anywhere': 8,
#           'are': 2,
#           'be': 4,
#           'boat': 3,
#           'box': 7,
#           'car': 7,
#           'could': 14,
#           'dark': 7,
#           'do': 37,
#           'eat': 23,
#           'eggs': 12,
#           'fox': 7,
#           'goat': 4,
#           'good': 2,
#           'greem': 1,
#           'green': 11,
#           'ham': 12,
#           'here': 11,
#           'house': 8,
#           'i': 71,
#           'if': 1,
#           'in': 40,
#           'let': 4,
#           'like': 44,
#           'may': 4,
#           'me': 4,
#           'mouse': 7,
#           'not': 82,
#           'on': 6,
#           'or': 8,
#           'rain': 4,
#           'sam': 7,
#           'samiam': 11,
#           'say': 5,
#           'see': 4,
#           'so': 5,
#           'thank': 2,
#           'that': 3,
#           'the': 11,
#           'them': 57,
#           'themsamiam': 1,
#           'then': 1,
#           'there': 9,
#           'they': 2,
#           'train': 8,
#           'tree': 6,
#           'try': 4,
#           'will': 18,
#           'with': 18,
#           'would': 27,
#           'you': 34},
#  'good': {'a': 56,
#           'am': 4,
#           'and': 26,
#           'anywhere': 8,
#           'are': 2,
#           'be': 4,
#           'boat': 3,
#           'box': 7,
#           'car': 7,
#           'could': 14,
#           'dark': 7,
#           'do': 37,
#           'eat': 23,
#           'eggs': 12,
#           'fox': 7,
#           'goat': 4,
#           'good': 2,
#           'greem': 1,
#           'green': 11,
#           'ham': 12,
#           'here': 11,
#           'house': 8,
#           'i': 71,
#           'if': 1,
#           'in': 40,
#           'let': 4,
#           'like': 44,
#           'may': 4,
#           'me': 4,
#           'mouse': 7,
#           'not': 82,
#           'on': 6,
#           'or': 8,
#           'rain': 4,
#           'sam': 7,
#           'samiam': 11,
#           'say': 5,
#           'see': 4,
#           'so': 5,
#           'thank': 2,
#           'that': 3,
#           'the': 11,
#           'them': 57,
#           'themsamiam': 1,
#           'then': 1,
#           'there': 9,
#           'they': 2,
#           'train': 8,
#           'tree': 6,
#           'try': 4,
#           'will': 18,
#           'with': 18,
#           'would': 27,
#           'you': 34},
#  'greem': {'a': 56,
#            'am': 4,
#            'and': 26,
#            'anywhere': 8,
#            'are': 2,
#            'be': 4,
#            'boat': 3,
#            'box': 7,
#            'car': 7,
#            'could': 14,
#            'dark': 7,
#            'do': 37,
#            'eat': 23,
#            'eggs': 12,
#            'fox': 7,
#            'goat': 4,
#            'good': 2,
#            'greem': 1,
#            'green': 11,
#            'ham': 12,
#            'here': 11,
#            'house': 8,
#            'i': 71,
#            'if': 1,
#            'in': 40,
#            'let': 4,
#            'like': 44,
#            'may': 4,
#            'me': 4,
#            'mouse': 7,
#            'not': 82,
#            'on': 6,
#            'or': 8,
#            'rain': 4,
#            'sam': 7,
#            'samiam': 11,
#            'say': 5,
#            'see': 4,
#            'so': 5,
#            'thank': 2,
#            'that': 3,
#            'the': 11,
#            'them': 57,
#            'themsamiam': 1,
#            'then': 1,
#            'there': 9,
#            'they': 2,
#            'train': 8,
#            'tree': 6,
#            'try': 4,
#            'will': 18,
#            'with': 18,
#            'would': 27,
#            'you': 34},
#  'green': {'a': 56,
#            'am': 4,
#            'and': 26,
#            'anywhere': 8,
#            'are': 2,
#            'be': 4,
#            'boat': 3,
#            'box': 7,
#            'car': 7,
#            'could': 14,
#            'dark': 7,
#            'do': 37,
#            'eat': 23,
#            'eggs': 12,
#            'fox': 7,
#            'goat': 4,
#            'good': 2,
#            'greem': 1,
#            'green': 11,
#            'ham': 12,
#            'here': 11,
#            'house': 8,
#            'i': 71,
#            'if': 1,
#            'in': 40,
#            'let': 4,
#            'like': 44,
#            'may': 4,
#            'me': 4,
#            'mouse': 7,
#            'not': 82,
#            'on': 6,
#            'or': 8,
#            'rain': 4,
#            'sam': 7,
#            'samiam': 11,
#            'say': 5,
#            'see': 4,
#            'so': 5,
#            'thank': 2,
#            'that': 3,
#            'the': 11,
#            'them': 57,
#            'themsamiam': 1,
#            'then': 1,
#            'there': 9,
#            'they': 2,
#            'train': 8,
#            'tree': 6,
#            'try': 4,
#            'will': 18,
#            'with': 18,
#            'would': 27,
#            'you': 34},
#  'ham': {'a': 56,
#          'am': 4,
#          'and': 26,
#          'anywhere': 8,
#          'are': 2,
#          'be': 4,
#          'boat': 3,
#          'box': 7,
#          'car': 7,
#          'could': 14,
#          'dark': 7,
#          'do': 37,
#          'eat': 23,
#          'eggs': 12,
#          'fox': 7,
#          'goat': 4,
#          'good': 2,
#          'greem': 1,
#          'green': 11,
#          'ham': 12,
#          'here': 11,
#          'house': 8,
#          'i': 71,
#          'if': 1,
#          'in': 40,
#          'let': 4,
#          'like': 44,
#          'may': 4,
#          'me': 4,
#          'mouse': 7,
#          'not': 82,
#          'on': 6,
#          'or': 8,
#          'rain': 4,
#          'sam': 7,
#          'samiam': 11,
#          'say': 5,
#          'see': 4,
#          'so': 5,
#          'thank': 2,
#          'that': 3,
#          'the': 11,
#          'them': 57,
#          'themsamiam': 1,
#          'then': 1,
#          'there': 9,
#          'they': 2,
#          'train': 8,
#          'tree': 6,
#          'try': 4,
#          'will': 18,
#          'with': 18,
#          'would': 27,
#          'you': 34},
#  'here': {'a': 56,
#           'am': 4,
#           'and': 26,
#           'anywhere': 8,
#           'are': 2,
#           'be': 4,
#           'boat': 3,
#           'box': 7,
#           'car': 7,
#           'could': 14,
#           'dark': 7,
#           'do': 37,
#           'eat': 23,
#           'eggs': 12,
#           'fox': 7,
#           'goat': 4,
#           'good': 2,
#           'greem': 1,
#           'green': 11,
#           'ham': 12,
#           'here': 11,
#           'house': 8,
#           'i': 71,
#           'if': 1,
#           'in': 40,
#           'let': 4,
#           'like': 44,
#           'may': 4,
#           'me': 4,
#           'mouse': 7,
#           'not': 82,
#           'on': 6,
#           'or': 8,
#           'rain': 4,
#           'sam': 7,
#           'samiam': 11,
#           'say': 5,
#           'see': 4,
#           'so': 5,
#           'thank': 2,
#           'that': 3,
#           'the': 11,
#           'them': 57,
#           'themsamiam': 1,
#           'then': 1,
#           'there': 9,
#           'they': 2,
#           'train': 8,
#           'tree': 6,
#           'try': 4,
#           'will': 18,
#           'with': 18,
#           'would': 27,
#           'you': 34},
#  'house': {'a': 56,
#            'am': 4,
#            'and': 26,
#            'anywhere': 8,
#            'are': 2,
#            'be': 4,
#            'boat': 3,
#            'box': 7,
#            'car': 7,
#            'could': 14,
#            'dark': 7,
#            'do': 37,
#            'eat': 23,
#            'eggs': 12,
#            'fox': 7,
#            'goat': 4,
#            'good': 2,
#            'greem': 1,
#            'green': 11,
#            'ham': 12,
#            'here': 11,
#            'house': 8,
#            'i': 71,
#            'if': 1,
#            'in': 40,
#            'let': 4,
#            'like': 44,
#            'may': 4,
#            'me': 4,
#            'mouse': 7,
#            'not': 82,
#            'on': 6,
#            'or': 8,
#            'rain': 4,
#            'sam': 7,
#            'samiam': 11,
#            'say': 5,
#            'see': 4,
#            'so': 5,
#            'thank': 2,
#            'that': 3,
#            'the': 11,
#            'them': 57,
#            'themsamiam': 1,
#            'then': 1,
#            'there': 9,
#            'they': 2,
#            'train': 8,
#            'tree': 6,
#            'try': 4,
#            'will': 18,
#            'with': 18,
#            'would': 27,
#            'you': 34},
#  'i': {'a': 56,
#        'am': 4,
#        'and': 26,
#        'anywhere': 8,
#        'are': 2,
#        'be': 4,
#        'boat': 3,
#        'box': 7,
#        'car': 7,
#        'could': 14,
#        'dark': 7,
#        'do': 37,
#        'eat': 23,
#        'eggs': 12,
#        'fox': 7,
#        'goat': 4,
#        'good': 2,
#        'greem': 1,
#        'green': 11,
#        'ham': 12,
#        'here': 11,
#        'house': 8,
#        'i': 71,
#        'if': 1,
#        'in': 40,
#        'let': 4,
#        'like': 44,
#        'may': 4,
#        'me': 4,
#        'mouse': 7,
#        'not': 82,
#        'on': 6,
#        'or': 8,
#        'rain': 4,
#        'sam': 7,
#        'samiam': 11,
#        'say': 5,
#        'see': 4,
#        'so': 5,
#        'thank': 2,
#        'that': 3,
#        'the': 11,
#        'them': 57,
#        'themsamiam': 1,
#        'then': 1,
#        'there': 9,
#        'they': 2,
#        'train': 8,
#        'tree': 6,
#        'try': 4,
#        'will': 18,
#        'with': 18,
#        'would': 27,
#        'you': 34},
#  'if': {'a': 56,
#         'am': 4,
#         'and': 26,
#         'anywhere': 8,
#         'are': 2,
#         'be': 4,
#         'boat': 3,
#         'box': 7,
#         'car': 7,
#         'could': 14,
#         'dark': 7,
#         'do': 37,
#         'eat': 23,
#         'eggs': 12,
#         'fox': 7,
#         'goat': 4,
#         'good': 2,
#         'greem': 1,
#         'green': 11,
#         'ham': 12,
#         'here': 11,
#         'house': 8,
#         'i': 71,
#         'if': 1,
#         'in': 40,
#         'let': 4,
#         'like': 44,
#         'may': 4,
#         'me': 4,
#         'mouse': 7,
#         'not': 82,
#         'on': 6,
#         'or': 8,
#         'rain': 4,
#         'sam': 7,
#         'samiam': 11,
#         'say': 5,
#         'see': 4,
#         'so': 5,
#         'thank': 2,
#         'that': 3,
#         'the': 11,
#         'them': 57,
#         'themsamiam': 1,
#         'then': 1,
#         'there': 9,
#         'they': 2,
#         'train': 8,
#         'tree': 6,
#         'try': 4,
#         'will': 18,
#         'with': 18,
#         'would': 27,
#         'you': 34},
#  'in': {'a': 56,
#         'am': 4,
#         'and': 26,
#         'anywhere': 8,
#         'are': 2,
#         'be': 4,
#         'boat': 3,
#         'box': 7,
#         'car': 7,
#         'could': 14,
#         'dark': 7,
#         'do': 37,
#         'eat': 23,
#         'eggs': 12,
#         'fox': 7,
#         'goat': 4,
#         'good': 2,
#         'greem': 1,
#         'green': 11,
#         'ham': 12,
#         'here': 11,
#         'house': 8,
#         'i': 71,
#         'if': 1,
#         'in': 40,
#         'let': 4,
#         'like': 44,
#         'may': 4,
#         'me': 4,
#         'mouse': 7,
#         'not': 82,
#         'on': 6,
#         'or': 8,
#         'rain': 4,
#         'sam': 7,
#         'samiam': 11,
#         'say': 5,
#         'see': 4,
#         'so': 5,
#         'thank': 2,
#         'that': 3,
#         'the': 11,
#         'them': 57,
#         'themsamiam': 1,
#         'then': 1,
#         'there': 9,
#         'they': 2,
#         'train': 8,
#         'tree': 6,
#         'try': 4,
#         'will': 18,
#         'with': 18,
#         'would': 27,
#         'you': 34},
#  'let': {'a': 56,
#          'am': 4,
#          'and': 26,
#          'anywhere': 8,
#          'are': 2,
#          'be': 4,
#          'boat': 3,
#          'box': 7,
#          'car': 7,
#          'could': 14,
#          'dark': 7,
#          'do': 37,
#          'eat': 23,
#          'eggs': 12,
#          'fox': 7,
#          'goat': 4,
#          'good': 2,
#          'greem': 1,
#          'green': 11,
#          'ham': 12,
#          'here': 11,
#          'house': 8,
#          'i': 71,
#          'if': 1,
#          'in': 40,
#          'let': 4,
#          'like': 44,
#          'may': 4,
#          'me': 4,
#          'mouse': 7,
#          'not': 82,
#          'on': 6,
#          'or': 8,
#          'rain': 4,
#          'sam': 7,
#          'samiam': 11,
#          'say': 5,
#          'see': 4,
#          'so': 5,
#          'thank': 2,
#          'that': 3,
#          'the': 11,
#          'them': 57,
#          'themsamiam': 1,
#          'then': 1,
#          'there': 9,
#          'they': 2,
#          'train': 8,
#          'tree': 6,
#          'try': 4,
#          'will': 18,
#          'with': 18,
#          'would': 27,
#          'you': 34},
#  'like': {'a': 56,
#           'am': 4,
#           'and': 26,
#           'anywhere': 8,
#           'are': 2,
#           'be': 4,
#           'boat': 3,
#           'box': 7,
#           'car': 7,
#           'could': 14,
#           'dark': 7,
#           'do': 37,
#           'eat': 23,
#           'eggs': 12,
#           'fox': 7,
#           'goat': 4,
#           'good': 2,
#           'greem': 1,
#           'green': 11,
#           'ham': 12,
#           'here': 11,
#           'house': 8,
#           'i': 71,
#           'if': 1,
#           'in': 40,
#           'let': 4,
#           'like': 44,
#           'may': 4,
#           'me': 4,
#           'mouse': 7,
#           'not': 82,
#           'on': 6,
#           'or': 8,
#           'rain': 4,
#           'sam': 7,
#           'samiam': 11,
#           'say': 5,
#           'see': 4,
#           'so': 5,
#           'thank': 2,
#           'that': 3,
#           'the': 11,
#           'them': 57,
#           'themsamiam': 1,
#           'then': 1,
#           'there': 9,
#           'they': 2,
#           'train': 8,
#           'tree': 6,
#           'try': 4,
#           'will': 18,
#           'with': 18,
#           'would': 27,
#           'you': 34},
#  'may': {'a': 56,
#          'am': 4,
#          'and': 26,
#          'anywhere': 8,
#          'are': 2,
#          'be': 4,
#          'boat': 3,
#          'box': 7,
#          'car': 7,
#          'could': 14,
#          'dark': 7,
#          'do': 37,
#          'eat': 23,
#          'eggs': 12,
#          'fox': 7,
#          'goat': 4,
#          'good': 2,
#          'greem': 1,
#          'green': 11,
#          'ham': 12,
#          'here': 11,
#          'house': 8,
#          'i': 71,
#          'if': 1,
#          'in': 40,
#          'let': 4,
#          'like': 44,
#          'may': 4,
#          'me': 4,
#          'mouse': 7,
#          'not': 82,
#          'on': 6,
#          'or': 8,
#          'rain': 4,
#          'sam': 7,
#          'samiam': 11,
#          'say': 5,
#          'see': 4,
#          'so': 5,
#          'thank': 2,
#          'that': 3,
#          'the': 11,
#          'them': 57,
#          'themsamiam': 1,
#          'then': 1,
#          'there': 9,
#          'they': 2,
#          'train': 8,
#          'tree': 6,
#          'try': 4,
#          'will': 18,
#          'with': 18,
#          'would': 27,
#          'you': 34},
#  'me': {'a': 56,
#         'am': 4,
#         'and': 26,
#         'anywhere': 8,
#         'are': 2,
#         'be': 4,
#         'boat': 3,
#         'box': 7,
#         'car': 7,
#         'could': 14,
#         'dark': 7,
#         'do': 37,
#         'eat': 23,
#         'eggs': 12,
#         'fox': 7,
#         'goat': 4,
#         'good': 2,
#         'greem': 1,
#         'green': 11,
#         'ham': 12,
#         'here': 11,
#         'house': 8,
#         'i': 71,
#         'if': 1,
#         'in': 40,
#         'let': 4,
#         'like': 44,
#         'may': 4,
#         'me': 4,
#         'mouse': 7,
#         'not': 82,
#         'on': 6,
#         'or': 8,
#         'rain': 4,
#         'sam': 7,
#         'samiam': 11,
#         'say': 5,
#         'see': 4,
#         'so': 5,
#         'thank': 2,
#         'that': 3,
#         'the': 11,
#         'them': 57,
#         'themsamiam': 1,
#         'then': 1,
#         'there': 9,
#         'they': 2,
#         'train': 8,
#         'tree': 6,
#         'try': 4,
#         'will': 18,
#         'with': 18,
#         'would': 27,
#         'you': 34},
#  'mouse': {'a': 56,
#            'am': 4,
#            'and': 26,
#            'anywhere': 8,
#            'are': 2,
#            'be': 4,
#            'boat': 3,
#            'box': 7,
#            'car': 7,
#            'could': 14,
#            'dark': 7,
#            'do': 37,
#            'eat': 23,
#            'eggs': 12,
#            'fox': 7,
#            'goat': 4,
#            'good': 2,
#            'greem': 1,
#            'green': 11,
#            'ham': 12,
#            'here': 11,
#            'house': 8,
#            'i': 71,
#            'if': 1,
#            'in': 40,
#            'let': 4,
#            'like': 44,
#            'may': 4,
#            'me': 4,
#            'mouse': 7,
#            'not': 82,
#            'on': 6,
#            'or': 8,
#            'rain': 4,
#            'sam': 7,
#            'samiam': 11,
#            'say': 5,
#            'see': 4,
#            'so': 5,
#            'thank': 2,
#            'that': 3,
#            'the': 11,
#            'them': 57,
#            'themsamiam': 1,
#            'then': 1,
#            'there': 9,
#            'they': 2,
#            'train': 8,
#            'tree': 6,
#            'try': 4,
#            'will': 18,
#            'with': 18,
#            'would': 27,
#            'you': 34},
#  'not': {'a': 56,
#          'am': 4,
#          'and': 26,
#          'anywhere': 8,
#          'are': 2,
#          'be': 4,
#          'boat': 3,
#          'box': 7,
#          'car': 7,
#          'could': 14,
#          'dark': 7,
#          'do': 37,
#          'eat': 23,
#          'eggs': 12,
#          'fox': 7,
#          'goat': 4,
#          'good': 2,
#          'greem': 1,
#          'green': 11,
#          'ham': 12,
#          'here': 11,
#          'house': 8,
#          'i': 71,
#          'if': 1,
#          'in': 40,
#          'let': 4,
#          'like': 44,
#          'may': 4,
#          'me': 4,
#          'mouse': 7,
#          'not': 82,
#          'on': 6,
#          'or': 8,
#          'rain': 4,
#          'sam': 7,
#          'samiam': 11,
#          'say': 5,
#          'see': 4,
#          'so': 5,
#          'thank': 2,
#          'that': 3,
#          'the': 11,
#          'them': 57,
#          'themsamiam': 1,
#          'then': 1,
#          'there': 9,
#          'they': 2,
#          'train': 8,
#          'tree': 6,
#          'try': 4,
#          'will': 18,
#          'with': 18,
#          'would': 27,
#          'you': 34},
#  'on': {'a': 56,
#         'am': 4,
#         'and': 26,
#         'anywhere': 8,
#         'are': 2,
#         'be': 4,
#         'boat': 3,
#         'box': 7,
#         'car': 7,
#         'could': 14,
#         'dark': 7,
#         'do': 37,
#         'eat': 23,
#         'eggs': 12,
#         'fox': 7,
#         'goat': 4,
#         'good': 2,
#         'greem': 1,
#         'green': 11,
#         'ham': 12,
#         'here': 11,
#         'house': 8,
#         'i': 71,
#         'if': 1,
#         'in': 40,
#         'let': 4,
#         'like': 44,
#         'may': 4,
#         'me': 4,
#         'mouse': 7,
#         'not': 82,
#         'on': 6,
#         'or': 8,
#         'rain': 4,
#         'sam': 7,
#         'samiam': 11,
#         'say': 5,
#         'see': 4,
#         'so': 5,
#         'thank': 2,
#         'that': 3,
#         'the': 11,
#         'them': 57,
#         'themsamiam': 1,
#         'then': 1,
#         'there': 9,
#         'they': 2,
#         'train': 8,
#         'tree': 6,
#         'try': 4,
#         'will': 18,
#         'with': 18,
#         'would': 27,
#         'you': 34},
#  'or': {'a': 56,
#         'am': 4,
#         'and': 26,
#         'anywhere': 8,
#         'are': 2,
#         'be': 4,
#         'boat': 3,
#         'box': 7,
#         'car': 7,
#         'could': 14,
#         'dark': 7,
#         'do': 37,
#         'eat': 23,
#         'eggs': 12,
#         'fox': 7,
#         'goat': 4,
#         'good': 2,
#         'greem': 1,
#         'green': 11,
#         'ham': 12,
#         'here': 11,
#         'house': 8,
#         'i': 71,
#         'if': 1,
#         'in': 40,
#         'let': 4,
#         'like': 44,
#         'may': 4,
#         'me': 4,
#         'mouse': 7,
#         'not': 82,
#         'on': 6,
#         'or': 8,
#         'rain': 4,
#         'sam': 7,
#         'samiam': 11,
#         'say': 5,
#         'see': 4,
#         'so': 5,
#         'thank': 2,
#         'that': 3,
#         'the': 11,
#         'them': 57,
#         'themsamiam': 1,
#         'then': 1,
#         'there': 9,
#         'they': 2,
#         'train': 8,
#         'tree': 6,
#         'try': 4,
#         'will': 18,
#         'with': 18,
#         'would': 27,
#         'you': 34},
#  'rain': {'a': 56,
#           'am': 4,
#           'and': 26,
#           'anywhere': 8,
#           'are': 2,
#           'be': 4,
#           'boat': 3,
#           'box': 7,
#           'car': 7,
#           'could': 14,
#           'dark': 7,
#           'do': 37,
#           'eat': 23,
#           'eggs': 12,
#           'fox': 7,
#           'goat': 4,
#           'good': 2,
#           'greem': 1,
#           'green': 11,
#           'ham': 12,
#           'here': 11,
#           'house': 8,
#           'i': 71,
#           'if': 1,
#           'in': 40,
#           'let': 4,
#           'like': 44,
#           'may': 4,
#           'me': 4,
#           'mouse': 7,
#           'not': 82,
#           'on': 6,
#           'or': 8,
#           'rain': 4,
#           'sam': 7,
#           'samiam': 11,
#           'say': 5,
#           'see': 4,
#           'so': 5,
#           'thank': 2,
#           'that': 3,
#           'the': 11,
#           'them': 57,
#           'themsamiam': 1,
#           'then': 1,
#           'there': 9,
#           'they': 2,
#           'train': 8,
#           'tree': 6,
#           'try': 4,
#           'will': 18,
#           'with': 18,
#           'would': 27,
#           'you': 34},
#  'sam': {'a': 56,
#          'am': 4,
#          'and': 26,
#          'anywhere': 8,
#          'are': 2,
#          'be': 4,
#          'boat': 3,
#          'box': 7,
#          'car': 7,
#          'could': 14,
#          'dark': 7,
#          'do': 37,
#          'eat': 23,
#          'eggs': 12,
#          'fox': 7,
#          'goat': 4,
#          'good': 2,
#          'greem': 1,
#          'green': 11,
#          'ham': 12,
#          'here': 11,
#          'house': 8,
#          'i': 71,
#          'if': 1,
#          'in': 40,
#          'let': 4,
#          'like': 44,
#          'may': 4,
#          'me': 4,
#          'mouse': 7,
#          'not': 82,
#          'on': 6,
#          'or': 8,
#          'rain': 4,
#          'sam': 7,
#          'samiam': 11,
#          'say': 5,
#          'see': 4,
#          'so': 5,
#          'thank': 2,
#          'that': 3,
#          'the': 11,
#          'them': 57,
#          'themsamiam': 1,
#          'then': 1,
#          'there': 9,
#          'they': 2,
#          'train': 8,
#          'tree': 6,
#          'try': 4,
#          'will': 18,
#          'with': 18,
#          'would': 27,
#          'you': 34},
#  'samiam': {'a': 56,
#             'am': 4,
#             'and': 26,
#             'anywhere': 8,
#             'are': 2,
#             'be': 4,
#             'boat': 3,
#             'box': 7,
#             'car': 7,
#             'could': 14,
#             'dark': 7,
#             'do': 37,
#             'eat': 23,
#             'eggs': 12,
#             'fox': 7,
#             'goat': 4,
#             'good': 2,
#             'greem': 1,
#             'green': 11,
#             'ham': 12,
#             'here': 11,
#             'house': 8,
#             'i': 71,
#             'if': 1,
#             'in': 40,
#             'let': 4,
#             'like': 44,
#             'may': 4,
#             'me': 4,
#             'mouse': 7,
#             'not': 82,
#             'on': 6,
#             'or': 8,
#             'rain': 4,
#             'sam': 7,
#             'samiam': 11,
#             'say': 5,
#             'see': 4,
#             'so': 5,
#             'thank': 2,
#             'that': 3,
#             'the': 11,
#             'them': 57,
#             'themsamiam': 1,
#             'then': 1,
#             'there': 9,
#             'they': 2,
#             'train': 8,
#             'tree': 6,
#             'try': 4,
#             'will': 18,
#             'with': 18,
#             'would': 27,
#             'you': 34},
#  'say': {'a': 56,
#          'am': 4,
#          'and': 26,
#          'anywhere': 8,
#          'are': 2,
#          'be': 4,
#          'boat': 3,
#          'box': 7,
#          'car': 7,
#          'could': 14,
#          'dark': 7,
#          'do': 37,
#          'eat': 23,
#          'eggs': 12,
#          'fox': 7,
#          'goat': 4,
#          'good': 2,
#          'greem': 1,
#          'green': 11,
#          'ham': 12,
#          'here': 11,
#          'house': 8,
#          'i': 71,
#          'if': 1,
#          'in': 40,
#          'let': 4,
#          'like': 44,
#          'may': 4,
#          'me': 4,
#          'mouse': 7,
#          'not': 82,
#          'on': 6,
#          'or': 8,
#          'rain': 4,
#          'sam': 7,
#          'samiam': 11,
#          'say': 5,
#          'see': 4,
#          'so': 5,
#          'thank': 2,
#          'that': 3,
#          'the': 11,
#          'them': 57,
#          'themsamiam': 1,
#          'then': 1,
#          'there': 9,
#          'they': 2,
#          'train': 8,
#          'tree': 6,
#          'try': 4,
#          'will': 18,
#          'with': 18,
#          'would': 27,
#          'you': 34},
#  'see': {'a': 56,
#          'am': 4,
#          'and': 26,
#          'anywhere': 8,
#          'are': 2,
#          'be': 4,
#          'boat': 3,
#          'box': 7,
#          'car': 7,
#          'could': 14,
#          'dark': 7,
#          'do': 37,
#          'eat': 23,
#          'eggs': 12,
#          'fox': 7,
#          'goat': 4,
#          'good': 2,
#          'greem': 1,
#          'green': 11,
#          'ham': 12,
#          'here': 11,
#          'house': 8,
#          'i': 71,
#          'if': 1,
#          'in': 40,
#          'let': 4,
#          'like': 44,
#          'may': 4,
#          'me': 4,
#          'mouse': 7,
#          'not': 82,
#          'on': 6,
#          'or': 8,
#          'rain': 4,
#          'sam': 7,
#          'samiam': 11,
#          'say': 5,
#          'see': 4,
#          'so': 5,
#          'thank': 2,
#          'that': 3,
#          'the': 11,
#          'them': 57,
#          'themsamiam': 1,
#          'then': 1,
#          'there': 9,
#          'they': 2,
#          'train': 8,
#          'tree': 6,
#          'try': 4,
#          'will': 18,
#          'with': 18,
#          'would': 27,
#          'you': 34},
#  'so': {'a': 56,
#         'am': 4,
#         'and': 26,
#         'anywhere': 8,
#         'are': 2,
#         'be': 4,
#         'boat': 3,
#         'box': 7,
#         'car': 7,
#         'could': 14,
#         'dark': 7,
#         'do': 37,
#         'eat': 23,
#         'eggs': 12,
#         'fox': 7,
#         'goat': 4,
#         'good': 2,
#         'greem': 1,
#         'green': 11,
#         'ham': 12,
#         'here': 11,
#         'house': 8,
#         'i': 71,
#         'if': 1,
#         'in': 40,
#         'let': 4,
#         'like': 44,
#         'may': 4,
#         'me': 4,
#         'mouse': 7,
#         'not': 82,
#         'on': 6,
#         'or': 8,
#         'rain': 4,
#         'sam': 7,
#         'samiam': 11,
#         'say': 5,
#         'see': 4,
#         'so': 5,
#         'thank': 2,
#         'that': 3,
#         'the': 11,
#         'them': 57,
#         'themsamiam': 1,
#         'then': 1,
#         'there': 9,
#         'they': 2,
#         'train': 8,
#         'tree': 6,
#         'try': 4,
#         'will': 18,
#         'with': 18,
#         'would': 27,
#         'you': 34},
#  'thank': {'a': 56,
#            'am': 4,
#            'and': 26,
#            'anywhere': 8,
#            'are': 2,
#            'be': 4,
#            'boat': 3,
#            'box': 7,
#            'car': 7,
#            'could': 14,
#            'dark': 7,
#            'do': 37,
#            'eat': 23,
#            'eggs': 12,
#            'fox': 7,
#            'goat': 4,
#            'good': 2,
#            'greem': 1,
#            'green': 11,
#            'ham': 12,
#            'here': 11,
#            'house': 8,
#            'i': 71,
#            'if': 1,
#            'in': 40,
#            'let': 4,
#            'like': 44,
#            'may': 4,
#            'me': 4,
#            'mouse': 7,
#            'not': 82,
#            'on': 6,
#            'or': 8,
#            'rain': 4,
#            'sam': 7,
#            'samiam': 11,
#            'say': 5,
#            'see': 4,
#            'so': 5,
#            'thank': 2,
#            'that': 3,
#            'the': 11,
#            'them': 57,
#            'themsamiam': 1,
#            'then': 1,
#            'there': 9,
#            'they': 2,
#            'train': 8,
#            'tree': 6,
#            'try': 4,
#            'will': 18,
#            'with': 18,
#            'would': 27,
#            'you': 34},
#  'that': {'a': 56,
#           'am': 4,
#           'and': 26,
#           'anywhere': 8,
#           'are': 2,
#           'be': 4,
#           'boat': 3,
#           'box': 7,
#           'car': 7,
#           'could': 14,
#           'dark': 7,
#           'do': 37,
#           'eat': 23,
#           'eggs': 12,
#           'fox': 7,
#           'goat': 4,
#           'good': 2,
#           'greem': 1,
#           'green': 11,
#           'ham': 12,
#           'here': 11,
#           'house': 8,
#           'i': 71,
#           'if': 1,
#           'in': 40,
#           'let': 4,
#           'like': 44,
#           'may': 4,
#           'me': 4,
#           'mouse': 7,
#           'not': 82,
#           'on': 6,
#           'or': 8,
#           'rain': 4,
#           'sam': 7,
#           'samiam': 11,
#           'say': 5,
#           'see': 4,
#           'so': 5,
#           'thank': 2,
#           'that': 3,
#           'the': 11,
#           'them': 57,
#           'themsamiam': 1,
#           'then': 1,
#           'there': 9,
#           'they': 2,
#           'train': 8,
#           'tree': 6,
#           'try': 4,
#           'will': 18,
#           'with': 18,
#           'would': 27,
#           'you': 34},
#  'the': {'a': 56,
#          'am': 4,
#          'and': 26,
#          'anywhere': 8,
#          'are': 2,
#          'be': 4,
#          'boat': 3,
#          'box': 7,
#          'car': 7,
#          'could': 14,
#          'dark': 7,
#          'do': 37,
#          'eat': 23,
#          'eggs': 12,
#          'fox': 7,
#          'goat': 4,
#          'good': 2,
#          'greem': 1,
#          'green': 11,
#          'ham': 12,
#          'here': 11,
#          'house': 8,
#          'i': 71,
#          'if': 1,
#          'in': 40,
#          'let': 4,
#          'like': 44,
#          'may': 4,
#          'me': 4,
#          'mouse': 7,
#          'not': 82,
#          'on': 6,
#          'or': 8,
#          'rain': 4,
#          'sam': 7,
#          'samiam': 11,
#          'say': 5,
#          'see': 4,
#          'so': 5,
#          'thank': 2,
#          'that': 3,
#          'the': 11,
#          'them': 57,
#          'themsamiam': 1,
#          'then': 1,
#          'there': 9,
#          'they': 2,
#          'train': 8,
#          'tree': 6,
#          'try': 4,
#          'will': 18,
#          'with': 18,
#          'would': 27,
#          'you': 34},
#  'them': {'a': 56,
#           'am': 4,
#           'and': 26,
#           'anywhere': 8,
#           'are': 2,
#           'be': 4,
#           'boat': 3,
#           'box': 7,
#           'car': 7,
#           'could': 14,
#           'dark': 7,
#           'do': 37,
#           'eat': 23,
#           'eggs': 12,
#           'fox': 7,
#           'goat': 4,
#           'good': 2,
#           'greem': 1,
#           'green': 11,
#           'ham': 12,
#           'here': 11,
#           'house': 8,
#           'i': 71,
#           'if': 1,
#           'in': 40,
#           'let': 4,
#           'like': 44,
#           'may': 4,
#           'me': 4,
#           'mouse': 7,
#           'not': 82,
#           'on': 6,
#           'or': 8,
#           'rain': 4,
#           'sam': 7,
#           'samiam': 11,
#           'say': 5,
#           'see': 4,
#           'so': 5,
#           'thank': 2,
#           'that': 3,
#           'the': 11,
#           'them': 57,
#           'themsamiam': 1,
#           'then': 1,
#           'there': 9,
#           'they': 2,
#           'train': 8,
#           'tree': 6,
#           'try': 4,
#           'will': 18,
#           'with': 18,
#           'would': 27,
#           'you': 34},
#  'themsamiam': {'a': 56,
#                 'am': 4,
#                 'and': 26,
#                 'anywhere': 8,
#                 'are': 2,
#                 'be': 4,
#                 'boat': 3,
#                 'box': 7,
#                 'car': 7,
#                 'could': 14,
#                 'dark': 7,
#                 'do': 37,
#                 'eat': 23,
#                 'eggs': 12,
#                 'fox': 7,
#                 'goat': 4,
#                 'good': 2,
#                 'greem': 1,
#                 'green': 11,
#                 'ham': 12,
#                 'here': 11,
#                 'house': 8,
#                 'i': 71,
#                 'if': 1,
#                 'in': 40,
#                 'let': 4,
#                 'like': 44,
#                 'may': 4,
#                 'me': 4,
#                 'mouse': 7,
#                 'not': 82,
#                 'on': 6,
#                 'or': 8,
#                 'rain': 4,
#                 'sam': 7,
#                 'samiam': 11,
#                 'say': 5,
#                 'see': 4,
#                 'so': 5,
#                 'thank': 2,
#                 'that': 3,
#                 'the': 11,
#                 'them': 57,
#                 'themsamiam': 1,
#                 'then': 1,
#                 'there': 9,
#                 'they': 2,
#                 'train': 8,
#                 'tree': 6,
#                 'try': 4,
#                 'will': 18,
#                 'with': 18,
#                 'would': 27,
#                 'you': 34},
#  'then': {'a': 56,
#           'am': 4,
#           'and': 26,
#           'anywhere': 8,
#           'are': 2,
#           'be': 4,
#           'boat': 3,
#           'box': 7,
#           'car': 7,
#           'could': 14,
#           'dark': 7,
#           'do': 37,
#           'eat': 23,
#           'eggs': 12,
#           'fox': 7,
#           'goat': 4,
#           'good': 2,
#           'greem': 1,
#           'green': 11,
#           'ham': 12,
#           'here': 11,
#           'house': 8,
#           'i': 71,
#           'if': 1,
#           'in': 40,
#           'let': 4,
#           'like': 44,
#           'may': 4,
#           'me': 4,
#           'mouse': 7,
#           'not': 82,
#           'on': 6,
#           'or': 8,
#           'rain': 4,
#           'sam': 7,
#           'samiam': 11,
#           'say': 5,
#           'see': 4,
#           'so': 5,
#           'thank': 2,
#           'that': 3,
#           'the': 11,
#           'them': 57,
#           'themsamiam': 1,
#           'then': 1,
#           'there': 9,
#           'they': 2,
#           'train': 8,
#           'tree': 6,
#           'try': 4,
#           'will': 18,
#           'with': 18,
#           'would': 27,
#           'you': 34},
#  'there': {'a': 56,
#            'am': 4,
#            'and': 26,
#            'anywhere': 8,
#            'are': 2,
#            'be': 4,
#            'boat': 3,
#            'box': 7,
#            'car': 7,
#            'could': 14,
#            'dark': 7,
#            'do': 37,
#            'eat': 23,
#            'eggs': 12,
#            'fox': 7,
#            'goat': 4,
#            'good': 2,
#            'greem': 1,
#            'green': 11,
#            'ham': 12,
#            'here': 11,
#            'house': 8,
#            'i': 71,
#            'if': 1,
#            'in': 40,
#            'let': 4,
#            'like': 44,
#            'may': 4,
#            'me': 4,
#            'mouse': 7,
#            'not': 82,
#            'on': 6,
#            'or': 8,
#            'rain': 4,
#            'sam': 7,
#            'samiam': 11,
#            'say': 5,
#            'see': 4,
#            'so': 5,
#            'thank': 2,
#            'that': 3,
#            'the': 11,
#            'them': 57,
#            'themsamiam': 1,
#            'then': 1,
#            'there': 9,
#            'they': 2,
#            'train': 8,
#            'tree': 6,
#            'try': 4,
#            'will': 18,
#            'with': 18,
#            'would': 27,
#            'you': 34},
#  'they': {'a': 56,
#           'am': 4,
#           'and': 26,
#           'anywhere': 8,
#           'are': 2,
#           'be': 4,
#           'boat': 3,
#           'box': 7,
#           'car': 7,
#           'could': 14,
#           'dark': 7,
#           'do': 37,
#           'eat': 23,
#           'eggs': 12,
#           'fox': 7,
#           'goat': 4,
#           'good': 2,
#           'greem': 1,
#           'green': 11,
#           'ham': 12,
#           'here': 11,
#           'house': 8,
#           'i': 71,
#           'if': 1,
#           'in': 40,
#           'let': 4,
#           'like': 44,
#           'may': 4,
#           'me': 4,
#           'mouse': 7,
#           'not': 82,
#           'on': 6,
#           'or': 8,
#           'rain': 4,
#           'sam': 7,
#           'samiam': 11,
#           'say': 5,
#           'see': 4,
#           'so': 5,
#           'thank': 2,
#           'that': 3,
#           'the': 11,
#           'them': 57,
#           'themsamiam': 1,
#           'then': 1,
#           'there': 9,
#           'they': 2,
#           'train': 8,
#           'tree': 6,
#           'try': 4,
#           'will': 18,
#           'with': 18,
#           'would': 27,
#           'you': 34},
#  'train': {'a': 56,
#            'am': 4,
#            'and': 26,
#            'anywhere': 8,
#            'are': 2,
#            'be': 4,
#            'boat': 3,
#            'box': 7,
#            'car': 7,
#            'could': 14,
#            'dark': 7,
#            'do': 37,
#            'eat': 23,
#            'eggs': 12,
#            'fox': 7,
#            'goat': 4,
#            'good': 2,
#            'greem': 1,
#            'green': 11,
#            'ham': 12,
#            'here': 11,
#            'house': 8,
#            'i': 71,
#            'if': 1,
#            'in': 40,
#            'let': 4,
#            'like': 44,
#            'may': 4,
#            'me': 4,
#            'mouse': 7,
#            'not': 82,
#            'on': 6,
#            'or': 8,
#            'rain': 4,
#            'sam': 7,
#            'samiam': 11,
#            'say': 5,
#            'see': 4,
#            'so': 5,
#            'thank': 2,
#            'that': 3,
#            'the': 11,
#            'them': 57,
#            'themsamiam': 1,
#            'then': 1,
#            'there': 9,
#            'they': 2,
#            'train': 8,
#            'tree': 6,
#            'try': 4,
#            'will': 18,
#            'with': 18,
#            'would': 27,
#            'you': 34},
#  'tree': {'a': 56,
#           'am': 4,
#           'and': 26,
#           'anywhere': 8,
#           'are': 2,
#           'be': 4,
#           'boat': 3,
#           'box': 7,
#           'car': 7,
#           'could': 14,
#           'dark': 7,
#           'do': 37,
#           'eat': 23,
#           'eggs': 12,
#           'fox': 7,
#           'goat': 4,
#           'good': 2,
#           'greem': 1,
#           'green': 11,
#           'ham': 12,
#           'here': 11,
#           'house': 8,
#           'i': 71,
#           'if': 1,
#           'in': 40,
#           'let': 4,
#           'like': 44,
#           'may': 4,
#           'me': 4,
#           'mouse': 7,
#           'not': 82,
#           'on': 6,
#           'or': 8,
#           'rain': 4,
#           'sam': 7,
#           'samiam': 11,
#           'say': 5,
#           'see': 4,
#           'so': 5,
#           'thank': 2,
#           'that': 3,
#           'the': 11,
#           'them': 57,
#           'themsamiam': 1,
#           'then': 1,
#           'there': 9,
#           'they': 2,
#           'train': 8,
#           'tree': 6,
#           'try': 4,
#           'will': 18,
#           'with': 18,
#           'would': 27,
#           'you': 34},
#  'try': {'a': 56,
#          'am': 4,
#          'and': 26,
#          'anywhere': 8,
#          'are': 2,
#          'be': 4,
#          'boat': 3,
#          'box': 7,
#          'car': 7,
#          'could': 14,
#          'dark': 7,
#          'do': 37,
#          'eat': 23,
#          'eggs': 12,
#          'fox': 7,
#          'goat': 4,
#          'good': 2,
#          'greem': 1,
#          'green': 11,
#          'ham': 12,
#          'here': 11,
#          'house': 8,
#          'i': 71,
#          'if': 1,
#          'in': 40,
#          'let': 4,
#          'like': 44,
#          'may': 4,
#          'me': 4,
#          'mouse': 7,
#          'not': 82,
#          'on': 6,
#          'or': 8,
#          'rain': 4,
#          'sam': 7,
#          'samiam': 11,
#          'say': 5,
#          'see': 4,
#          'so': 5,
#          'thank': 2,
#          'that': 3,
#          'the': 11,
#          'them': 57,
#          'themsamiam': 1,
#          'then': 1,
#          'there': 9,
#          'they': 2,
#          'train': 8,
#          'tree': 6,
#          'try': 4,
#          'will': 18,
#          'with': 18,
#          'would': 27,
#          'you': 34},
#  'will': {'a': 56,
#           'am': 4,
#           'and': 26,
#           'anywhere': 8,
#           'are': 2,
#           'be': 4,
#           'boat': 3,
#           'box': 7,
#           'car': 7,
#           'could': 14,
#           'dark': 7,
#           'do': 37,
#           'eat': 23,
#           'eggs': 12,
#           'fox': 7,
#           'goat': 4,
#           'good': 2,
#           'greem': 1,
#           'green': 11,
#           'ham': 12,
#           'here': 11,
#           'house': 8,
#           'i': 71,
#           'if': 1,
#           'in': 40,
#           'let': 4,
#           'like': 44,
#           'may': 4,
#           'me': 4,
#           'mouse': 7,
#           'not': 82,
#           'on': 6,
#           'or': 8,
#           'rain': 4,
#           'sam': 7,
#           'samiam': 11,
#           'say': 5,
#           'see': 4,
#           'so': 5,
#           'thank': 2,
#           'that': 3,
#           'the': 11,
#           'them': 57,
#           'themsamiam': 1,
#           'then': 1,
#           'there': 9,
#           'they': 2,
#           'train': 8,
#           'tree': 6,
#           'try': 4,
#           'will': 18,
#           'with': 18,
#           'would': 27,
#           'you': 34},
#  'with': {'a': 56,
#           'am': 4,
#           'and': 26,
#           'anywhere': 8,
#           'are': 2,
#           'be': 4,
#           'boat': 3,
#           'box': 7,
#           'car': 7,
#           'could': 14,
#           'dark': 7,
#           'do': 37,
#           'eat': 23,
#           'eggs': 12,
#           'fox': 7,
#           'goat': 4,
#           'good': 2,
#           'greem': 1,
#           'green': 11,
#           'ham': 12,
#           'here': 11,
#           'house': 8,
#           'i': 71,
#           'if': 1,
#           'in': 40,
#           'let': 4,
#           'like': 44,
#           'may': 4,
#           'me': 4,
#           'mouse': 7,
#           'not': 82,
#           'on': 6,
#           'or': 8,
#           'rain': 4,
#           'sam': 7,
#           'samiam': 11,
#           'say': 5,
#           'see': 4,
#           'so': 5,
#           'thank': 2,
#           'that': 3,
#           'the': 11,
#           'them': 57,
#           'themsamiam': 1,
#           'then': 1,
#           'there': 9,
#           'they': 2,
#           'train': 8,
#           'tree': 6,
#           'try': 4,
#           'will': 18,
#           'with': 18,
#           'would': 27,
#           'you': 34},
#  'would': {'a': 56,
#            'am': 4,
#            'and': 26,
#            'anywhere': 8,
#            'are': 2,
#            'be': 4,
#            'boat': 3,
#            'box': 7,
#            'car': 7,
#            'could': 14,
#            'dark': 7,
#            'do': 37,
#            'eat': 23,
#            'eggs': 12,
#            'fox': 7,
#            'goat': 4,
#            'good': 2,
#            'greem': 1,
#            'green': 11,
#            'ham': 12,
#            'here': 11,
#            'house': 8,
#            'i': 71,
#            'if': 1,
#            'in': 40,
#            'let': 4,
#            'like': 44,
#            'may': 4,
#            'me': 4,
#            'mouse': 7,
#            'not': 82,
#            'on': 6,
#            'or': 8,
#            'rain': 4,
#            'sam': 7,
#            'samiam': 11,
#            'say': 5,
#            'see': 4,
#            'so': 5,
#            'thank': 2,
#            'that': 3,
#            'the': 11,
#            'them': 57,
#            'themsamiam': 1,
#            'then': 1,
#            'there': 9,
#            'they': 2,
#            'train': 8,
#            'tree': 6,
#            'try': 4,
#            'will': 18,
#            'with': 18,
#            'would': 27,
#            'you': 34},
#  'you': {'a': 56,
#          'am': 4,
#          'and': 26,
#          'anywhere': 8,
#          'are': 2,
#          'be': 4,
#          'boat': 3,
#          'box': 7,
#          'car': 7,
#          'could': 14,
#          'dark': 7,
#          'do': 37,
#          'eat': 23,
#          'eggs': 12,
#          'fox': 7,
#          'goat': 4,
#          'good': 2,
#          'greem': 1,
#          'green': 11,
#          'ham': 12,
#          'here': 11,
#          'house': 8,
#          'i': 71,
#          'if': 1,
#          'in': 40,
#          'let': 4,
#          'like': 44,
#          'may': 4,
#          'me': 4,
#          'mouse': 7,
#          'not': 82,
#          'on': 6,
#          'or': 8,
#          'rain': 4,
#          'sam': 7,
#          'samiam': 11,
#          'say': 5,
#          'see': 4,
#          'so': 5,
#          'thank': 2,
#          'that': 3,
#          'the': 11,
#          'them': 57,
#          'themsamiam': 1,
#          'then': 1,
#          'there': 9,
#          'they': 2,
#          'train': 8,
#          'tree': 6,
#          'try': 4,
#          'will': 18,
#          'with': 18,
#          'would': 27,
#          'you': 34}}

# %%
# seuss_dict = markov_dict()

# import pandas as pd
# seuss_cols = ['past', 'present', 'chance']
seuss_df = pd.DataFrame.from_dict(word_freqs,
                                  orient='index',
                                  columns=['past', 'present', 'chance'])
# print(seuss_df)
# s_path = os.path('/data/seuss_csv.csv')
seuss_csv = seuss_df.to_csv('seuss_csv', index=False, header=[
                            'past', 'present', 'chance'])
# def markov_chain():
input_dict = markov_dict()
for value_dict in input_dict.values():
    print(sum(value_dict.values()))

# print(g.words)
# markov_chain()

# likely_hood = seuss_talk[probs]

# word_freqs = word_freqs['words']['values']
# for k, v in word_freqs.items():
#     probs = k.v
#     print(probs)

# for word in past_word:
#     print(word)
# for probs in word:
#     print(word)

# if frequency.value is not None:

#     for value in frequency:
#         print(value)

# %%
import random
import re
import string


def markov_dict():
    # create empty dictionary
    global word_freqs
    global frequency
    word_freqs = {}
    # open txt file and read to string, string to lower
    with open('./seuss_script.txt', 'r') as seuss_script:
        seussical = seuss_script.read()
        seussical = seussical.lower()
    # use regex to split text into words and punctuation

    words = re.sub('['+string.punctuation+']', '', seussical).split()
    past_word = ""
    frequency = {}
    # for loop that runs over every word in test
    for word in words:
        # if past_word is in dict, assign it to 'frequency'
        if past_word in word_freqs:
            frequency = word_freqs[past_word]
        # if not, create empty dictionary with past_word as the key and frequency as the value
        else:

            word_freqs[past_word] = frequency

        if word in frequency:
            frequency[word] += 1
        else:
            frequency[word] = 1
        past_word = word

    return word_freqs

    # for word in word_freqs:
    #     for value in word:
    #         probs = sum(word.value)
    # for word in word_freqs:
    #     for value in word.value:
    #         value = word_freqs[word][frequency]
    #         print(value)


markov_dict()

# %%
# def seuss_chain():

# seuss_chain()
for word in word_freqs:
    for value in word:
        probs = sum(word.value)

# %%
# import random

# names = ["Kelly", "Scott", "Emma", "Jon"]
# for i in range(3):
#     item = random.choices(names, cum_weights=(5, 15, 30, 50), k=1)
#     print("Iteration:", i, "Weighted Random choice is", item[0])


# numberList = [111, 222, 333, 444, 555]
# print(random.choices(numberList, weights=(10, 20, 30, 40, 50), k=5))


# key2_value = (example_dict.get('key1') or {}).get('key2')

# value = example_dict['key1']['key2'] if example_dict.get(
#     'key1') and example_dict['key1'].get('key2') else default_value
