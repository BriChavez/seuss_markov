# %%
import re
import string


def markov_dict():
    """create a dict of how what words follow which and how many times they did"""
    with open('./seuss_script.txt', 'r') as seuss_script:
        # open txt file and read to string, string to lower
        seussical = seuss_script.read()
        seussical = seussical.lower()
        word_freqs = {}
        # use regex to split text into words and punctuation
        global seuss_string
        seuss_string = re.sub('['+string.punctuation+']', '', seussical).split()
        past_word = ""
        frequency = {}
        # for loop that runs over every word in test
        for word in seuss_string:
            # if past_word is in dict, assign it to 'frequency'
            if past_word in word_freqs:
                frequency = word_freqs[past_word]
            # if not, create empty dictionary with past_word as the key and frequency as the value
            else:
                word_freqs[past_word] = frequency

            if word in frequency:
                frequency[word] += 1
            else:
                frequency[word] = 1

            past_word = word

        return word_freqs

markov_dict()
# name our new dictionary of words and count of next possible words to a new variable
seuss_dict = markov_dict()
print(seuss_dict)

# %%
"""start the story"""

# name variable with the first word in our list of words
first_word = seuss_string[0]
story = []
# current_word = "yay"
def start_story(list):
    """function to start the story"""
    if story == []:
        # set story up with a first word
        story.append(first_word)
        # call the global variable current_word so we can change it
        # global current_word
        # turn the first word into the current word
        # current_word = first_word
        # print(current_word)
    else:
        # dont start the story if its already been started
        pass
    return story
start_story(seuss_string)
# call function on our list of words from the text
seuss_list = seuss_string
# print(story)

# reset current word to the last word of the story
current_word = story[-1]
print(current_word)

# %%
current_word = story[-1]
# print(current_word)
# def next_up(list):
# if len(story) == 1:
#     print("okay")

for next_up, inner_dict in seuss_dict.items():
    total_occurances = inner_dict.values()
    word_self_total = inner_dict.items()
    if next_up == current_word:
        word_num = word_self_total

        total = sum(total_occurances)
        print(total)
        for number in total_occurances:
            # total = sum(total_occurances)
            probs = number / total
            # print(type(number))
            # print(type(total_occurances))
            print(probs)
        # for key in inner_dict:
        #     print(key + ':', inner_dict[key])
        #     # print(next_up)

# %%
current_word = story[-1]
# print(current_word)
# def next_up(list):
# if len(story) == 1:
#     print("okay")

for next_up, inner_dict in seuss_dict.items():
    total_occurances = inner_dict.values()
    word_self_total = inner_dict.items()
    if next_up == current_word:
        word_num = word_self_total

        # total = sum(total_occurances)
        # print(total)
        # for number in total_occurances:
        #     # total = sum(total_occurances)
        #     probs = number / total
        #     # print(type(number))
        #     # print(type(total_occurances))
        #     print(probs)
        # for key in inner_dict:
        #     print(key + ':', inner_dict[key])
        #     # print(next_up)

# %%
current_word = story[-1]
print(current_word)
# def next_up(list):
if len(story) == 1:
    print("okay")
# if story[0] == first_word:
for p_id, p_info in seuss_dict.items():
    print("\nPerson ID:", p_id)
    if p_id == current_word:
        for key in p_info:
            print(key + ':', p_info[key])
            print(p_info)
# Out:
# green
#
# Person ID:
#
# Person ID: green
# green: 11
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# eggs: 12
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# and: 26
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# ham: 12
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# i: 71
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# am: 4
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# sam: 7
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# that: 3
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# samiam: 11
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# do: 37
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# not: 82
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# like: 44
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# would: 27
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# you: 34
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# themsamiam: 1
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# them: 57
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# here: 11
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# or: 8
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# there: 9
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# anywhere: 8
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# in: 40
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# a: 56
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# house: 8
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# then: 1
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# with: 18
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# mouse: 7
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# eat: 23
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# box: 7
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# fox: 7
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# could: 14
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# car: 7
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# they: 2
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# are: 2
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# may: 4
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# will: 18
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# see: 4
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# tree: 6
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# let: 4
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# me: 4
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# be: 4
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# train: 8
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# on: 6
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# greem: 1
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# say: 5
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# the: 11
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# dark: 7
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# rain: 4
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# goat: 4
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# boat: 3
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# so: 5
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# try: 4
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# if: 1
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# good: 2
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# thank: 2
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
#
# Person ID: eggs
#
# Person ID: and
#
# Person ID: ham
#
# Person ID: i
#
# Person ID: am
#
# Person ID: sam
#
# Person ID: that
#
# Person ID: samiam
#
# Person ID: do
#
# Person ID: not
#
# Person ID: like
#
# Person ID: would
#
# Person ID: you
#
# Person ID: themsamiam
#
# Person ID: them
#
# Person ID: here
#
# Person ID: or
#
# Person ID: there
#
# Person ID: anywhere
#
# Person ID: in
#
# Person ID: a
#
# Person ID: house
#
# Person ID: then
#
# Person ID: with
#
# Person ID: mouse
#
# Person ID: eat
#
# Person ID: box
#
# Person ID: fox
#
# Person ID: could
#
# Person ID: car
#
# Person ID: they
#
# Person ID: are
#
# Person ID: may
#
# Person ID: will
#
# Person ID: see
#
# Person ID: tree
#
# Person ID: let
#
# Person ID: me
#
# Person ID: be
#
# Person ID: train
#
# Person ID: on
#
# Person ID: greem
#
# Person ID: say
#
# Person ID: the
#
# Person ID: dark
#
# Person ID: rain
#
# Person ID: goat
#
# Person ID: boat
#
# Person ID: so
#
# Person ID: try
#
# Person ID: if
#
# Person ID: good
#
# Person ID: thank

# %%
# def next_up(list):

# if story[0] == first_word:
for current_word, word_count in seuss_dict.items():
    print("\ncurrent_word", current_word)
    if current_word == current_word:
        for how_often in word_count[how_often]:
            # print(word_count[how_often])
            # print(how_often + ':', word_count[how_often])
            # print(type(word_count[how_often]))
            print(how_often)
# Out:
# current_word
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3821/2576476622.py in <module>
#       5     print("\ncurrent_word", current_word)
#       6     if current_word == current_word:
# ----> 7         for how_often in word_count[how_often]:
#       8             # print(word_count[how_often])
#       9             # print(how_often + ':', word_count[how_often])
#
# TypeError: 'int' object is not iterable

# %%
"""start the story"""

# name variable with the first word in our list of words
first_word = seuss_string[0]
story = []
# current_word = "yay"
def start_story(list):
    """function to start the story"""
    if story == []:
        # set story up with a first word
        story.append(first_word)
        # call the global variable current_word so we can change it
        # global current_word
        # turn the first word into the current word
        # current_word = first_word
        # print(current_word)
    else:
        # dont start the story if its already been started
        pass
    return story
start_story(seuss_string)
# call function on our list of words from the text
seuss_list = seuss_string
# print(story)

# reset current word to the last word of the story
current_word = story[-1]
print(current_word)
# Out:
# green

# %%
import re
import string


def markov_dict():
    # create empty dictionary
    # global word_freqs
    # global frequency
    # global past_word
    # open txt file and read to string, string to lower
    with open('./seuss_script.txt', 'r') as seuss_script:
        seussical = seuss_script.read()
        seussical = seussical.lower()
    # use regex to split text into words and punctuation
    words = re.sub('['+string.punctuation+']', '', seussical).split()
    first_word = words[0]
    story = []
    # past_word = story[-1]
    
    # start the story

    first_word = words[0]
    story = []
    

    def start_story(list):
        """function to start the story"""
        if story == []:
            # set story up with a first word
            story.append(first_word)
            # turn the first word into the current wird
            current_word = first_word
        else:
            pass
        return story, current_word
    start_story(words)
    
    

            # for d, k, v in seuss_dict.items():
                
                # next_up(story)
                # next_up = k, y[k]
#             return line_up
# for word in line_up:
    # if len(story) == len(first_word):
    #     story = story + [' cat']
    #     # do the thing for finding the second word
    #     # story.append(past_word)
    #     print(story)


    # frequency = {}

    # for loop that runs over every word in test
    # print(story)
    # print(past_word)





seuss_dict = markov_dict()
# print(seuss_dict)

# def line_up
# for word, next in seuss_dict.items():
#     append(word)
#     # and

# def seuss_script(dict):
#     story = []
#     last_word = []
#     for word in dict:
#         if word not in last_word:
#             story = append.story(word)
# def line_up(dictionary):
#     for x, y in dictionary.items():

#         for k in y:
#             line_up = x , k, y[k]
#             # next_up = k, y[k]
#             return line_up
# for word in line_up:


# # this word print
# # next word is based of the probability of the next word
# #  get value of all


#             # current_next_chance = {x},[k],[y[k]]
#                 print(line_up)
#                 print(next_up)
# line_up(seuss_dict)

# print()

# def line_up(dictionary):
#     for x, y in dictionary.items():

#         for k in y:
#             line_up = x, k, y[k]


# for woird in dictuonary
#     for next in word
#        tot percent = sum of count
# def line_up(dictionary):
#     for x, y in dictionary.items():

#         for k in y:
#             line_up = x , k, y[k]
#             # next_up = k, y[k]
#             return line_up
# for word in line_up:
#         next.value/sum of count
#         rng based off percent
#             next word = current word
#             story. append.

# seuss_it_up(seuss_dict)
# """
# take key.
# take next word.
# calculate chance with their value/sum of.
# rng the word.
# add that word to story.
# grab that word from the dict key.
# make that word key.
# calculate next word."""

# for value_dict in input_dict.values():
#     print(sum(value_dict.values()))
# Out:
# ['green']
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3821/2860972696.py in <module>
#      73
#      74
# ---> 75 seuss_dict = markov_dict()
#      76 # print(seuss_dict)
#      77
#
# /tmp/ipykernel_3821/2860972696.py in markov_dict()
#      43
#      44     # if story[0] == first_word:
# ---> 45     for p_id, p_info in seuss_dict.items():
#      46         print("\nPerson ID:", p_id)
#      47         if p_id == current_word:
#
# AttributeError: 'NoneType' object has no attribute 'items'

# %%
import collections
global story


def seuss_it_up(dict):
    total_follows = []
    for word, int in dict.items():
        likely = int
        print(likely)
    #         if word not in total_follows:
    #             total_follows.append(word)
    # print(total_follows)
    last_word = total_follows.endswith(current_word)
    if current_word == last_word:
        

# ini_dict = [{'a': 5, 'b': 10, 'c': 90},
#             {'a': 45, 'b': 78},
#             {'a': 90, 'c': 10}]
# SEUSS_DICT =

# word = [{next: prob}]
# # printing initial dictionary
# print("initial dictionary", str(ini_dict))

# # sum the values with same keys
# counter = collections.Counter()
# for d in ini_dict:
#     counter.update(d)

# result = dict(counter)


# print("resultant dictionary : ", str(counter))

seuss_it_up(seuss_dict)


# Initialising list of dictionary

# for word in dict:
#     for next in word.items():
#         counts = next[1]
#         # total = sum(counts)

#         print(counts)
# for key, value in next.items():

#     return    # for value in key:

# if word in story: psss
#      else:
#          for

# current = key
# likelyhood = value
# print(current, likelyhood)

# print(next_word)
# print(key, value)
# Out:
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}
# {'green': 11, 'eggs': 12, 'and': 26, 'ham': 12, 'i': 71, 'am': 4, 'sam': 7, 'that': 3, 'samiam': 11, 'do': 37, 'not': 82, 'like': 44, 'would': 27, 'you': 34, 'themsamiam': 1, 'them': 57, 'here': 11, 'or': 8, 'there': 9, 'anywhere': 8, 'in': 40, 'a': 56, 'house': 8, 'then': 1, 'with': 18, 'mouse': 7, 'eat': 23, 'box': 7, 'fox': 7, 'could': 14, 'car': 7, 'they': 2, 'are': 2, 'may': 4, 'will': 18, 'see': 4, 'tree': 6, 'let': 4, 'me': 4, 'be': 4, 'train': 8, 'on': 6, 'greem': 1, 'say': 5, 'the': 11, 'dark': 7, 'rain': 4, 'goat': 4, 'boat': 3, 'so': 5, 'try': 4, 'if': 1, 'good': 2, 'thank': 2}

# %%
# for id, info in D.items():
#     print("\nEmployee ID:", id)
#     for key in info:
#         print(key + ':', info[key])

# for key in seuss_dict.keys():
#     for key in key.keys():
#         print(value)


# def get_keys(dictionary):
#     inner_pairs = []
#     for key, value in dictionary.items():
#         if type(value) is dict:
#             new_keys = get_keys(value)
#             inner_pairs.append(key)
#             for innerkey in new_keys:
#                 inner_pairs.append(f'{key}/{innerkey}')
#         else:
#             inner_pairs.append(key)
#     return inner_pairs

# for k, v, items in seuss_dict.keys():
#     print(k[v][items])

# for key, values in seuss_dict:
#     past = key
#     next = values
#     print(past)

# %%
def word_probs(dictionary):
    inner_pairs = []
    for key, value in dictionary.items():
        if type(value) is dict:
            new_keys = word_probs(value)
            inner_pairs.append(key)
            for inner_key in new_keys:
                inner_pairs.append(f'{key}:{inner_key}')
        else:
            inner_pairs.append(key)
    return inner_pairs


word_probs(seuss_dict)

# %%
# seuss_dict = markov_dict()

# import pandas as pd
# seuss_cols = ['past', 'present', 'chance']
seuss_df = pd.DataFrame.from_dict(word_freqs,
                                  orient='index',
                                  columns=['past', 'present', 'chance'])
# print(seuss_df)
# s_path = os.path('/data/seuss_csv.csv')
seuss_csv = seuss_df.to_csv('seuss_csv', index=False, header=[
                            'past', 'present', 'chance'])
# def markov_chain():
input_dict = markov_dict()
for value_dict in input_dict.values():
    print(sum(value_dict.values()))

# print(g.words)
# markov_chain()

# likely_hood = seuss_talk[probs]

# word_freqs = word_freqs['words']['values']
# for k, v in word_freqs.items():
#     probs = k.v
#     print(probs)

# for word in past_word:
#     print(word)
# for probs in word:
#     print(word)

# if frequency.value is not None:

#     for value in frequency:
#         print(value)
# Out:
#   File "/tmp/ipykernel_96418/1904928728.py", line 12
#     input_dict = markov_dict()
#     ^
# IndentationError: unexpected indent

# %%
import random
import re
import string


def markov_dict():
    # create empty dictionary
    global word_freqs
    global frequency
    word_freqs = {}
    # open txt file and read to string, string to lower
    with open('./seuss_script.txt', 'r') as seuss_script:
        seussical = seuss_script.read()
        seussical = seussical.lower()
    # use regex to split text into words and punctuation

    words = re.sub('['+string.punctuation+']', '', seussical).split()
    past_word = ""
    frequency = {}
    # for loop that runs over every word in test
    for word in words:
        # if past_word is in dict, assign it to 'frequency'
        if past_word in word_freqs:
            frequency = word_freqs[past_word]
        # if not, create empty dictionary with past_word as the key and frequency as the value
        else:

            word_freqs[past_word] = frequency

        if word in frequency:
            frequency[word] += 1
        else:
            frequency[word] = 1
        past_word = word

    return word_freqs

    # for word in word_freqs:
    #     for value in word:
    #         probs = sum(word.value)
    # for word in word_freqs:
    #     for value in word.value:
    #         value = word_freqs[word][frequency]
    #         print(value)


markov_dict()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_70538/1256649175.py in <module>
#      49
#      50
# ---> 51 markov_dict()
#      52
#      53
#
# ~/data/dont_worry_about_it/dr_seuss_markov/venv/lib/python3.7/site-packages/IPython/core/displayhook.py in __call__(self, result)
#     260             self.start_displayhook()
#     261             self.write_output_prompt()
# --> 262             format_dict, md_dict = self.compute_format_data(result)
#     263             self.update_user_ns(result)
#     264             self.fill_exec_result(result)
#
# ~/data/dont_worry_about_it/dr_seuss_markov/venv/lib/python3.7/site-packages/IPython/core/displayhook.py in compute_format_data(self, result)
#     149
#     150         """
# --> 151         return self.shell.display_formatter.format(result)
#     152
#     153     # This can be set to True by the write_output_prompt method in a subclass
#
# ~/data/dont_worry_about_it/dr_seuss_markov/venv/lib/python3.7/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~/data/dont_worry_about_it/dr_seuss_markov/venv/lib/python3.7/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/data/dont_worry_about_it/dr_seuss_markov/venv/lib/python3.7/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/data/dont_worry_about_it/dr_seuss_markov/venv/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# ~/data/dont_worry_about_it/dr_seuss_markov/venv/lib/python3.7/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     375                 if cls in self.type_pprinters:
#     376                     # printer registered in self.type_pprinters
# --> 377                     return self.type_pprinters[cls](obj, self, cycle)
#     378                 else:
#     379                     # deferred printer
#
# ~/data/dont_worry_about_it/dr_seuss_markov/venv/lib/python3.7/site-packages/IPython/lib/pretty.py in inner(obj, p, cycle)
#     605             p.pretty(key)
#     606             p.text(': ')
# --> 607             p.pretty(obj[key])
#     608         p.end_group(step, end)
#     609     return inner
#
# ~/data/dont_worry_about_it/dr_seuss_markov/venv/lib/python3.7/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     375                 if cls in self.type_pprinters:
#     376                     # printer registered in self.type_pprinters
# --> 377                     return self.type_pprinters[cls](obj, self, cycle)
#     378                 else:
#     379                     # deferred printer
#
# ~/data/dont_worry_about_it/dr_seuss_markov/venv/lib/python3.7/site-packages/IPython/lib/pretty.py in inner(obj, p, cycle)
#     605             p.pretty(key)
#     606             p.text(': ')
# --> 607             p.pretty(obj[key])
#     608         p.end_group(step, end)
#     609     return inner
#
# ~/data/dont_worry_about_it/dr_seuss_markov/venv/lib/python3.7/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     361         self.begin_group()
#     362         try:
# --> 363             obj_class = _safe_getattr(obj, '__class__', None) or type(obj)
#     364             # First try to find registered singleton printers for the type.
#     365             try:
#
# ~/data/dont_worry_about_it/dr_seuss_markov/venv/lib/python3.7/site-packages/IPython/lib/pretty.py in _safe_getattr(obj, attr, default)
#     107     """
#     108     try:
# --> 109         return getattr(obj, attr, default)
#     110     except Exception:
#     111         return default
#
# KeyboardInterrupt:

# %%
# def seuss_chain():

# seuss_chain()
for word in word_freqs:
    for value in word:
        probs = sum(word.value)

# %%
# import random

# names = ["Kelly", "Scott", "Emma", "Jon"]
# for i in range(3):
#     item = random.choices(names, cum_weights=(5, 15, 30, 50), k=1)
#     print("Iteration:", i, "Weighted Random choice is", item[0])


# numberList = [111, 222, 333, 444, 555]
# print(random.choices(numberList, weights=(10, 20, 30, 40, 50), k=5))


# key2_value = (example_dict.get('key1') or {}).get('key2')

# value = example_dict['key1']['key2'] if example_dict.get(
#     'key1') and example_dict['key1'].get('key2') else default_value
